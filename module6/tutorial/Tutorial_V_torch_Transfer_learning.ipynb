# %% [markdown]
# # Tutorial V: Transfer Learning

# %% [markdown]
# <p>
# Bern Winter School on Machine Learning, 2024<br>
# Prepared by Mykhailo Vladymyrov and Matthew Vowels.
# </p>
#
# This work is licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.

# %% [markdown]
# In this session we will use the pretrained Inception model to build own image classifier. We will aslo learn how to save our trained models.

# %% [markdown]
# ## 1. Load necessary libraries

# %%
colab = True # set to True is using google colab

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

import sys
import shutil
import tarfile

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.hub import download_url_to_file
from torchvision import transforms, datasets
from torch.utils.tensorboard import SummaryWriter

from sklearn.model_selection import train_test_split
from PIL import Image

# %load_ext tensorboard

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Download libraries

# %%
if colab:
    path = os.path.join(os.path.abspath('.')+'material.tgz')
    url = 'https://github.com/neworldemancer/BMLWS/raw/main/tut_files/tpub0320.tgz'
    # p = tf.keras.utils.get_file(path, url)
    # Download compressed file with torch utils

    download_url_to_file(url=url, dst=path)

    tar = tarfile.open(path, "r:gz")
    tar.extractall()
    tar.close()
# Out:
# 100%|██████████| 77.4M/77.4M [00:00<00:00, 194MB/s]

# %% [markdown]
# ## 2. Transfer learning

# %% [markdown]
# We load first an inception model with pretrained weights, without the final classifier:

# %%
print(torch.hub.help('pytorch/vision:v0.7.0', 'inception_v3'))
# Out:
# Downloading: "https://github.com/pytorch/vision/zipball/v0.7.0" to /root/.cache/torch/hub/v0.7.0.zip
#     Inception v3 model architecture from
#     `Rethinking the Inception Architecture for Computer Vision <http://arxiv.org/abs/1512.00567>`_.
#
#     .. note::
#         **Important**: In contrast to the other models the inception_v3 expects tensors with a size of
#         N x 3 x 299 x 299, so ensure your images are sized accordingly.
#
#     Args:
#         weights (:class:`~torchvision.models.Inception_V3_Weights`, optional): The
#             pretrained weights for the model. See
#             :class:`~torchvision.models.Inception_V3_Weights` below for
#             more details, and possible values. By default, no pre-trained
#             weights are used.
#         progress (bool, optional): If True, displays a progress bar of the
#             download to stderr. Default is True.
#         **kwargs: parameters passed to the ``torchvision.models.Inception3``
#             base class. Please refer to the `source code
#             <https://github.com/pytorch/vision/blob/main/torchvision/models/inception.py>`_
#             for more details about this class.
#
#     .. autoclass:: torchvision.models.Inception_V3_Weights
#         :members:

# %%
base_model = torch.hub.load('pytorch/vision:v0.7.0', 'inception_v3')
# Out:
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.7.0
# /usr/local/lib/python3.11/dist-packages/torchvision/models/inception.py:43: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn(

# %%
dir(base_model)
# Out:
# ['AuxLogits',
#  'Conv2d_1a_3x3',
#  'Conv2d_2a_3x3',
#  'Conv2d_2b_3x3',
#  'Conv2d_3b_1x1',
#  'Conv2d_4a_3x3',
#  'Mixed_5b',
#  'Mixed_5c',
#  'Mixed_5d',
#  'Mixed_6a',
#  'Mixed_6b',
#  'Mixed_6c',
#  'Mixed_6d',
#  'Mixed_6e',
#  'Mixed_7a',
#  'Mixed_7b',
#  'Mixed_7c',
#  'T_destination',
#  '__annotations__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_apply',
#  '_backward_hooks',
#  '_backward_pre_hooks',
#  '_buffers',
#  '_call_impl',
#  '_compiled_call_impl',
#  '_forward',
#  '_forward_hooks',
#  '_forward_hooks_always_called',
#  '_forward_hooks_with_kwargs',
#  '_forward_pre_hooks',
#  '_forward_pre_hooks_with_kwargs',
#  '_get_backward_hooks',
#  '_get_backward_pre_hooks',
#  '_get_name',
#  '_is_full_backward_hook',
#  '_load_from_state_dict',
#  '_load_state_dict_post_hooks',
#  '_load_state_dict_pre_hooks',
#  '_maybe_warn_non_full_backward_hook',
#  '_modules',
#  '_named_members',
#  '_non_persistent_buffers_set',
#  '_parameters',
#  '_register_load_state_dict_pre_hook',
#  '_register_state_dict_hook',
#  '_replicate_for_data_parallel',
#  '_save_to_state_dict',
#  '_slow_forward',
#  '_state_dict_hooks',
#  '_state_dict_pre_hooks',
#  '_transform_input',
#  '_version',
#  '_wrapped_call_impl',
#  'add_module',
#  'apply',
#  'aux_logits',
#  'avgpool',
#  'bfloat16',
#  'buffers',
#  'call_super_init',
#  'children',
#  'compile',
#  'cpu',
#  'cuda',
#  'double',
#  'dropout',
#  'dump_patches',
#  'eager_outputs',
#  'eval',
#  'extra_repr',
#  'fc',
#  'float',
#  'forward',
#  'get_buffer',
#  'get_extra_state',
#  'get_parameter',
#  'get_submodule',
#  'half',
#  'ipu',
#  'load_state_dict',
#  'maxpool1',
#  'maxpool2',
#  'modules',
#  'mtia',
#  'named_buffers',
#  'named_children',
#  'named_modules',
#  'named_parameters',
#  'parameters',
#  'register_backward_hook',
#  'register_buffer',
#  'register_forward_hook',
#  'register_forward_pre_hook',
#  'register_full_backward_hook',
#  'register_full_backward_pre_hook',
#  'register_load_state_dict_post_hook',
#  'register_load_state_dict_pre_hook',
#  'register_module',
#  'register_parameter',
#  'register_state_dict_post_hook',
#  'register_state_dict_pre_hook',
#  'requires_grad_',
#  'set_extra_state',
#  'set_submodule',
#  'share_memory',
#  'state_dict',
#  'to',
#  'to_empty',
#  'train',
#  'training',
#  'transform_input',
#  'type',
#  'xpu',
#  'zero_grad']

# %%
base_model
# Out:
# Inception3(
#   (Conv2d_1a_3x3): BasicConv2d(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2a_3x3): BasicConv2d(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2b_3x3): BasicConv2d(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Conv2d_3b_1x1): BasicConv2d(
#     (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_4a_3x3): BasicConv2d(
#     (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Mixed_5b): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5c): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5d): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6a): InceptionB(
#     (branch3x3): BasicConv2d(
#       (conv): Conv2d(288, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6b): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6c): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6d): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6e): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (AuxLogits): InceptionAux(
#     (conv0): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv1): BasicConv2d(
#       (conv): Conv2d(128, 768, kernel_size=(5, 5), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (fc): Linear(in_features=768, out_features=1000, bias=True)
#   )
#   (Mixed_7a): InceptionD(
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2): BasicConv2d(
#       (conv): Conv2d(192, 320, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7b): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(1280, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(1280, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(1280, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(1280, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7c): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(2048, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(2048, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(2048, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(2048, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
writer = SummaryWriter('runs/inspect_inception_v3')
xs = torch.zeros(1, 3, 299, 299)
writer.add_graph(base_model, xs)
writer.close()

# %%
#%tensorboard --logdir=runs/inspect_inception_v3

# %% [markdown]
# And build a new model using it:

# %%
def fc_head(in_features, n_classes):
    return nn.Sequential(
        nn.Linear(in_features, 64),
        nn.Sigmoid(),
        nn.Linear(64, n_classes)
    )

# %%
# freeze the parameters of the base model
for param in base_model.parameters():
    param.requires_grad = False

# replace existing fc layer with our 2-layer classication head
in_features = base_model.fc.in_features
n_classes = 2
base_model.fc = fc_head(in_features, n_classes)
model = base_model.to(device)

# %%
# Loss function
criterion = nn.CrossEntropyLoss()
# Optimizer
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
def get_predictions(logits):
    # no need to apply softmax, as softmax is a monotonic function
    # probs = F.softmax(logits, dim=1)
    _, predictions = torch.max(logits, dim=1)
    return predictions

# %%
def calculate_accuracy_batch(predictions, labels):
    n_correct = torch.sum(predictions == labels).item()
    n_total = len(labels)
    return n_correct, n_total

# %% [markdown]
# ## 3. Dataset

# %% [markdown]
# The Inception network is trained on natural images: thigs we see around everyday, like sky, flowers, animals, building, cars.
# It builds an hierarchy of features, to describe what it sees.
# This features can be used to train fast on different classes of objects. E.g. [here](https://www.tensorflow.org/tutorials/image_retraining) are more examples on transfer learning.
#
# Here you will see that these features can be even used to detect thngs very different from natural images. Namely we will try to use it to distinguish German text from Italian. We will use 100 samples, taken from 5 German and 5 Italian books, 10 samples each.

# %%
# load images from the ML3 folder into torch dataset

image_transform = transforms.Compose([
    transforms.Resize((299, 299)),

    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

dataset = datasets.ImageFolder('ML3', transform=image_transform)

# %%
text_label = dataset.classes
print(text_label)
# Out:
# ['de', 'it']

# %%
for im, lbl in dataset:
    print(lbl, im.shape, im.min(), im.max(), im.mean(), im.std())

    # convert tensor to numpy array, transpose from CHW to HWC and scale to range [0, 1]
    im_numpy = im.cpu().numpy().transpose(1,2,0)
    im_numpy -= im_numpy.min(axis=(0,1))
    im_numpy /= im_numpy.max(axis=(0,1))

    plt.figure(figsize=(2,2))
    plt.imshow(im_numpy)
    plt.show()
    break
# Out:
# 0 torch.Size([3, 299, 299]) tensor(-2.0837) tensor(2.6400) tensor(1.7154) tensor(1.2477)

# %%
#We will take 80% from each for training and 20 for validation

batch_size=10

dataset_tra, dataset_val = torch.utils.data.random_split(dataset, [0.8, 0.2])

# %% [markdown]
# Is this a good way? Why?

# %%
lbls = np.array([lbl for _, lbl in dataset_tra])
print(f'n_class_0 = {np.sum(lbls == 0)}, n_class_1 = {np.sum(lbls == 1)}')
# Out:
# n_class_0 = 40, n_class_1 = 40

# %% [markdown]
# it's better to have a balanced (strtifed) training and validation sets

# %%
n_samples = len(dataset)
lbls = np.array([lbl for _, lbl in dataset])

# obtain indeces of training and validation samples
idx_tra, idx_val = train_test_split(np.arange(len(dataset)), test_size=0.2, stratify=lbls)

dataset_tra = torch.utils.data.Subset(dataset, idx_tra)
dataset_val = torch.utils.data.Subset(dataset, idx_val)

# %%
lbls = np.array([lbl for _, lbl in dataset_tra])
print(f'Training dataset: n_class_0 = {np.sum(lbls == 0)}, n_class_1 = {np.sum(lbls == 1)}')

lbls = np.array([lbl for _, lbl in dataset_val])
print(f'Validation dataset: n_class_0 = {np.sum(lbls == 0)}, n_class_1 = {np.sum(lbls == 1)}')
# Out:
# Training dataset: n_class_0 = 40, n_class_1 = 40
# Validation dataset: n_class_0 = 10, n_class_1 = 10

# %%
# create data loaders
loader_tra = torch.utils.data.DataLoader(dataset_tra, batch_size=batch_size, shuffle=True)
loader_val = torch.utils.data.DataLoader(dataset_val, batch_size=batch_size, shuffle=False)

# %% [markdown]
# Lets see a sample:

# %%
ims, lbls = next(iter(loader_tra))  # get a batch from the training dataset
print(ims.shape, ims.min(), ims.max(), ims.mean(), ims.std())
for im, lbl in zip(ims, lbls):
    # convert tensor to numpy array, transpose from CHW to HWC and scale to range [0, 1]
    im_numpy = im.cpu().numpy().transpose(1,2,0)
    im_numpy -= im_numpy.min(axis=(0,1))
    im_numpy /= im_numpy.max(axis=(0,1))

    plt.figure(figsize=(2,2))
    plt.imshow(im_numpy)
    plt.title(text_label[lbl])
    plt.show()
# Out:
# torch.Size([10, 3, 299, 299]) tensor(-2.1179) tensor(2.6400) tensor(1.9340) tensor(1.0001)

# %%
model(ims.to(device))
# Out:
# InceptionOutputs(logits=tensor([[-0.1793, -0.1855],
#         [-0.1816, -0.1088],
#         [-0.2193, -0.1530],
#         [-0.1899, -0.1953],
#         [-0.1964, -0.1267],
#         [-0.2254, -0.1544],
#         [-0.2032, -0.0240],
#         [-0.1931, -0.2004],
#         [-0.2290, -0.1569],
#         [-0.2207, -0.2043]], device='cuda:0', grad_fn=<AddmmBackward0>), aux_logits=tensor([[ 0.0243, -0.0135, -0.0021,  ..., -0.0232,  0.0280,  0.0036],
#         [ 0.0314,  0.0192, -0.0072,  ..., -0.0202,  0.0232,  0.0013],
#         [-0.0097,  0.0053,  0.0045,  ..., -0.0389,  0.0272,  0.0206],
#         ...,
#         [ 0.0196,  0.0217,  0.0244,  ..., -0.0362,  0.0180, -0.0198],
#         [ 0.0263,  0.0243, -0.0030,  ..., -0.0325,  0.0474, -0.0149],
#         [ 0.0125,  0.0214,  0.0013,  ..., -0.0408,  0.0281,  0.0057]],
#        device='cuda:0'))

# %%
res = model(ims.to(device))

# %%
type(res)
# Out:
# torchvision.models.inception.InceptionOutputs

# %%
res
# Out:
# InceptionOutputs(logits=tensor([[-0.2278, -0.1195],
#         [-0.1894, -0.2032],
#         [-0.1495, -0.1375],
#         [-0.2075, -0.1793],
#         [-0.1984, -0.1712],
#         [-0.2266, -0.1670],
#         [-0.1232, -0.1523],
#         [-0.1934, -0.1494],
#         [-0.1719, -0.1319],
#         [-0.1727, -0.1959]], device='cuda:0', grad_fn=<AddmmBackward0>), aux_logits=tensor([[ 0.0243, -0.0135, -0.0021,  ..., -0.0232,  0.0280,  0.0036],
#         [ 0.0314,  0.0192, -0.0072,  ..., -0.0202,  0.0232,  0.0013],
#         [-0.0097,  0.0053,  0.0045,  ..., -0.0389,  0.0272,  0.0206],
#         ...,
#         [ 0.0196,  0.0217,  0.0244,  ..., -0.0362,  0.0180, -0.0198],
#         [ 0.0263,  0.0243, -0.0030,  ..., -0.0325,  0.0474, -0.0149],
#         [ 0.0125,  0.0214,  0.0013,  ..., -0.0408,  0.0281,  0.0057]],
#        device='cuda:0'))

# %%
logits = res.logits
logits.shape
# Out:
# torch.Size([10, 2])

# %% [markdown]
# ## 4. Training

# %% [markdown]
# The training is similar to what we saw previously.
#
# Since Inception model is big, this will take a while, even we use GPUs. On your laptop CPU this would probably take ~15 times longer. And we are not training the whole Inception! We have just small thing on top + a very small dataset!

# %% [markdown]
# We will use callback to save checkpoints on each iteration of training. They contain values of trainable variables.

# %%
def train(model, train_loader, criterion, optimizer):
    model.train()
    running_loss = 0.0
    n_correct_running = 0
    n_samples_running = 0
    for images, labels in train_loader:
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()  # reset gradients
        logits = model(images).logits
        loss = criterion(logits, labels)


        loss.backward()    # compute gradients
        optimizer.step()   # update parameters with gradients

        n_correct, n_samples = calculate_accuracy_batch(get_predictions(logits), labels)
        n_correct_running += n_correct
        n_samples_running += n_samples
        running_loss += loss.item()

    n = len(train_loader)
    return running_loss / n, n_correct_running / n_samples_running

def validate(model, val_loader, criterion):
    model.eval()
    running_loss = 0.0
    n_correct_running = 0
    n_samples_running = 0
    with torch.no_grad():
        for images, labels in val_loader:
            images = images.to(device)
            labels = labels.to(device)

            logits = model(images)  # at the inference the model outputs just the logits
            loss = criterion(logits, labels)

            n_correct, n_samples = calculate_accuracy_batch(get_predictions(logits), labels)
            n_correct_running += n_correct
            n_samples_running += n_samples
            running_loss += loss.item()

    n = len(val_loader)
    return running_loss / n, n_correct_running / n_samples_running

# %%
def train_model(model, criterion, optimizer, n_epochs, train_loader, val_loader, save_path):
    os.makedirs(save_path, exist_ok=True)

    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': [], 'epoch': []}

    for epoch in range(n_epochs):
        train_loss, train_acc = train(model, train_loader, criterion, optimizer)
        val_loss, val_acc = validate(model, val_loader, criterion)

        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc)
        history['val_loss'].append(val_loss)
        history['val_acc'].append(val_acc)
        history['epoch'].append(epoch)

        save_dict = {'epoch': epoch,
                     'model_state_dict': model.state_dict(),
                     'optimizer_state_dict': optimizer.state_dict(),
                     'history': history,
                     }
        torch.save(save_dict, os.path.join(save_path, f'model_epoch_{epoch:03d}.pth'))

        print(f'Epoch {epoch+1}/{n_epochs} | '
              f'train_loss: {train_loss:.4f}, train_acc: {train_acc:.4f} | '
              f'val_loss: {val_loss:.4f}, val_acc: {val_acc:.4f}')

    return history

# %%
def plot_history(history):
    fig, axs = plt.subplots(1, 2, figsize=(10,5))
    axs[0].plot(history['epoch'], history['train_loss'])
    axs[0].plot(history['epoch'], history['val_loss'])
    axs[0].legend(('training loss', 'validation loss'), loc='lower right')

    axs[1].plot(history['epoch'], history['train_acc'])
    axs[1].plot(history['epoch'], history['val_acc'])
    axs[1].legend(('training accuracy', 'validation accuracy'), loc='lower right')
    plt.show()

# %%
save_path = 'TL_1'

n_epochs=70

history = train_model(model, criterion, optimizer, n_epochs, loader_tra, loader_val, save_path)
# Out:
# Epoch 1/70 | train_loss: 0.5178, train_acc: 0.7500 | val_loss: 0.4213, val_acc: 0.8000
# Epoch 2/70 | train_loss: 0.5290, train_acc: 0.6875 | val_loss: 0.4289, val_acc: 0.8000
# Epoch 3/70 | train_loss: 0.4939, train_acc: 0.7250 | val_loss: 0.4198, val_acc: 0.8000
# Epoch 4/70 | train_loss: 0.5394, train_acc: 0.7000 | val_loss: 0.4225, val_acc: 0.8000
# Epoch 5/70 | train_loss: 0.4352, train_acc: 0.8125 | val_loss: 0.4219, val_acc: 0.8000
# Epoch 6/70 | train_loss: 0.5093, train_acc: 0.7125 | val_loss: 0.4300, val_acc: 0.8000
# Epoch 7/70 | train_loss: 0.4142, train_acc: 0.8250 | val_loss: 0.4197, val_acc: 0.8000
# Epoch 8/70 | train_loss: 0.4987, train_acc: 0.7375 | val_loss: 0.4410, val_acc: 0.7000
# Epoch 9/70 | train_loss: 0.5449, train_acc: 0.7250 | val_loss: 0.4163, val_acc: 0.7500
# Epoch 10/70 | train_loss: 0.5130, train_acc: 0.7250 | val_loss: 0.4306, val_acc: 0.8000
# Epoch 11/70 | train_loss: 0.5814, train_acc: 0.7125 | val_loss: 0.4167, val_acc: 0.8500
# Epoch 12/70 | train_loss: 0.5540, train_acc: 0.7000 | val_loss: 0.4526, val_acc: 0.7500
# Epoch 13/70 | train_loss: 0.6641, train_acc: 0.6000 | val_loss: 0.4343, val_acc: 0.8000
# Epoch 14/70 | train_loss: 0.4458, train_acc: 0.7875 | val_loss: 0.4341, val_acc: 0.8000
# Epoch 15/70 | train_loss: 0.4863, train_acc: 0.7875 | val_loss: 0.4203, val_acc: 0.9000
# Epoch 16/70 | train_loss: 0.4687, train_acc: 0.8250 | val_loss: 0.4094, val_acc: 0.8000
# Epoch 17/70 | train_loss: 0.5652, train_acc: 0.7000 | val_loss: 0.3970, val_acc: 0.8500
# Epoch 18/70 | train_loss: 0.5705, train_acc: 0.7500 | val_loss: 0.4982, val_acc: 0.7000
# Epoch 19/70 | train_loss: 0.5086, train_acc: 0.7125 | val_loss: 0.4196, val_acc: 0.7500
# Epoch 20/70 | train_loss: 0.4880, train_acc: 0.7625 | val_loss: 0.4440, val_acc: 0.8000
# Epoch 21/70 | train_loss: 0.4592, train_acc: 0.8000 | val_loss: 0.4167, val_acc: 0.8500
# Epoch 22/70 | train_loss: 0.4983, train_acc: 0.7625 | val_loss: 0.4144, val_acc: 0.8500
# Epoch 23/70 | train_loss: 0.5244, train_acc: 0.7375 | val_loss: 0.4157, val_acc: 0.8000
# Epoch 24/70 | train_loss: 0.4368, train_acc: 0.8000 | val_loss: 0.4142, val_acc: 0.8000
# Epoch 25/70 | train_loss: 0.5314, train_acc: 0.7500 | val_loss: 0.4269, val_acc: 0.8500
# Epoch 26/70 | train_loss: 0.5366, train_acc: 0.7625 | val_loss: 0.4292, val_acc: 0.8500
# Epoch 27/70 | train_loss: 0.4549, train_acc: 0.8125 | val_loss: 0.4104, val_acc: 0.8500
# Epoch 28/70 | train_loss: 0.4854, train_acc: 0.7500 | val_loss: 0.3720, val_acc: 0.9000
# Epoch 29/70 | train_loss: 0.4832, train_acc: 0.7750 | val_loss: 0.3803, val_acc: 0.9000
# Epoch 30/70 | train_loss: 0.4080, train_acc: 0.8125 | val_loss: 0.3992, val_acc: 0.8000
# Epoch 31/70 | train_loss: 0.5483, train_acc: 0.7500 | val_loss: 0.3767, val_acc: 0.8500
# Epoch 32/70 | train_loss: 0.5137, train_acc: 0.7500 | val_loss: 0.3868, val_acc: 0.9000
# Epoch 33/70 | train_loss: 0.4329, train_acc: 0.7875 | val_loss: 0.3908, val_acc: 0.8500
# Epoch 34/70 | train_loss: 0.4321, train_acc: 0.7875 | val_loss: 0.3998, val_acc: 0.8500
# Epoch 35/70 | train_loss: 0.3603, train_acc: 0.8500 | val_loss: 0.3790, val_acc: 0.8000
# Epoch 36/70 | train_loss: 0.4849, train_acc: 0.7750 | val_loss: 0.4005, val_acc: 0.8500
# Epoch 37/70 | train_loss: 0.4626, train_acc: 0.8000 | val_loss: 0.3819, val_acc: 0.8000
# Epoch 38/70 | train_loss: 0.4861, train_acc: 0.7625 | val_loss: 0.4216, val_acc: 0.7000
# Epoch 39/70 | train_loss: 0.4790, train_acc: 0.7375 | val_loss: 0.4052, val_acc: 0.8500
# Epoch 40/70 | train_loss: 0.5566, train_acc: 0.7375 | val_loss: 0.4043, val_acc: 0.8000
# Epoch 41/70 | train_loss: 0.5034, train_acc: 0.7375 | val_loss: 0.4780, val_acc: 0.7500
# Epoch 42/70 | train_loss: 0.4982, train_acc: 0.7375 | val_loss: 0.3625, val_acc: 0.8500
# Epoch 43/70 | train_loss: 0.4382, train_acc: 0.8125 | val_loss: 0.3625, val_acc: 0.8500
# Epoch 44/70 | train_loss: 0.5586, train_acc: 0.7375 | val_loss: 0.3723, val_acc: 0.8500
# Epoch 45/70 | train_loss: 0.4889, train_acc: 0.7750 | val_loss: 0.4152, val_acc: 0.8000
# Epoch 46/70 | train_loss: 0.4859, train_acc: 0.7625 | val_loss: 0.3807, val_acc: 0.9000
# Epoch 47/70 | train_loss: 0.6034, train_acc: 0.6875 | val_loss: 0.4176, val_acc: 0.8500
# Epoch 48/70 | train_loss: 0.3872, train_acc: 0.8250 | val_loss: 0.4133, val_acc: 0.8500
# Epoch 49/70 | train_loss: 0.4540, train_acc: 0.7500 | val_loss: 0.3873, val_acc: 0.8500
# Epoch 50/70 | train_loss: 0.5376, train_acc: 0.7125 | val_loss: 0.3738, val_acc: 0.8500
# Epoch 51/70 | train_loss: 0.5272, train_acc: 0.7125 | val_loss: 0.3899, val_acc: 0.8000
# Epoch 52/70 | train_loss: 0.5407, train_acc: 0.7375 | val_loss: 0.4031, val_acc: 0.7500
# Epoch 53/70 | train_loss: 0.4166, train_acc: 0.8000 | val_loss: 0.4533, val_acc: 0.7500
# Epoch 54/70 | train_loss: 0.4921, train_acc: 0.7625 | val_loss: 0.3700, val_acc: 0.8500
# Epoch 55/70 | train_loss: 0.4655, train_acc: 0.8375 | val_loss: 0.3709, val_acc: 0.8000
# Epoch 56/70 | train_loss: 0.4665, train_acc: 0.8125 | val_loss: 0.3882, val_acc: 0.8500
# Epoch 57/70 | train_loss: 0.4124, train_acc: 0.7750 | val_loss: 0.3716, val_acc: 0.8500
# Epoch 58/70 | train_loss: 0.5326, train_acc: 0.6875 | val_loss: 0.3747, val_acc: 0.8500
# Epoch 59/70 | train_loss: 0.5385, train_acc: 0.7125 | val_loss: 0.3832, val_acc: 0.8000
# Epoch 60/70 | train_loss: 0.6083, train_acc: 0.6500 | val_loss: 0.4792, val_acc: 0.7500
# Epoch 61/70 | train_loss: 0.4603, train_acc: 0.7250 | val_loss: 0.4023, val_acc: 0.9000
# Epoch 62/70 | train_loss: 0.4636, train_acc: 0.7750 | val_loss: 0.3907, val_acc: 0.8500
# Epoch 63/70 | train_loss: 0.4238, train_acc: 0.8500 | val_loss: 0.3801, val_acc: 0.9000
# Epoch 64/70 | train_loss: 0.4229, train_acc: 0.8250 | val_loss: 0.4010, val_acc: 0.8500
# Epoch 65/70 | train_loss: 0.4157, train_acc: 0.8250 | val_loss: 0.3665, val_acc: 0.9000
# Epoch 66/70 | train_loss: 0.5208, train_acc: 0.7250 | val_loss: 0.3901, val_acc: 0.8500
# Epoch 67/70 | train_loss: 0.4812, train_acc: 0.7625 | val_loss: 0.3831, val_acc: 0.8500
# Epoch 68/70 | train_loss: 0.4509, train_acc: 0.7875 | val_loss: 0.4036, val_acc: 0.8000
# Epoch 69/70 | train_loss: 0.6229, train_acc: 0.7000 | val_loss: 0.4653, val_acc: 0.8000
# Epoch 70/70 | train_loss: 0.4628, train_acc: 0.7875 | val_loss: 0.3976, val_acc: 0.8000

# %%
plot_history(history)

# %% [markdown]
# We see that training accuracy hits 100% quickly. Why do you think it happens? Consider that loss keeps decreasing.
# Also on such a small dataset our model overfits.

# %% [markdown]
# ## 5. Load trained variables

# %% [markdown]
# If we have the model already created we can easily load the saved training variables values from a checkpoint:

# %%
test_epochs = [0, 5, 11, 24, 69]
for ep in test_epochs:
    d = torch.load(os.path.join(save_path, f'model_epoch_{ep:03d}.pth'))

    model_state_dict = d['model_state_dict']
    model.load_state_dict(model_state_dict)

    loss, acc = validate(model, loader_val, criterion)
    print(f'Epoch {ep} | val_loss: {loss:.4f}, val_acc: {acc:.4f}')
# Out:
# <ipython-input-36-6e146456bed6>:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   d = torch.load(os.path.join(save_path, f'model_epoch_{ep:03d}.pth'))
# Epoch 0 | val_loss: 1.2061, val_acc: 0.5000
# Epoch 5 | val_loss: 0.5496, val_acc: 0.7500
# Epoch 11 | val_loss: 0.5381, val_acc: 0.7500
# Epoch 24 | val_loss: 0.4980, val_acc: 0.7500
# Epoch 69 | val_loss: 0.4207, val_acc: 0.8000

# %% [markdown]
# ## 6. Saving for inference.

# %% [markdown]
# In pytorch it's easy to save a model for inference:

# %%
# export the model for inference
torch.save(model, 'inference_model.pth')

# %% [markdown]
# ## 7. Inference

# %%
loaded_model = torch.load('inference_model.pth')
loaded_model = loaded_model.to(device)
loaded_model.eval();  # set the model to inference mode
# Out:
# <ipython-input-38-7191ecbc7d98>:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   loaded_model = torch.load('inference_model.pth')

# %%
# get an image:
im = Image.open('ML3/it/1_1.jpg')
# convert to tensor
im_tensor = image_transform(im)
# add batch dimension
im_tensor = im_tensor.unsqueeze(0).to(device)

print(im_tensor.shape)
# Out:
# torch.Size([1, 3, 299, 299])

# %%
# get the logits and class
with torch.no_grad():
    logits = loaded_model(im_tensor)
    probs = F.softmax(logits, dim=1)
    pred = get_predictions(logits)

probs = probs.cpu().numpy()[0]  # only one element in the batch
pred = pred.cpu().numpy()[0]
print(probs[pred], text_label[pred])
# Out:
# 0.8896289 it

# %% [markdown]
# ## 8. Improving the results

# %% [markdown]
# Often, as in this sample we don't have anough labeled data in hand. We need to use it as efficient as possible.
# One way to do it is to aply training data augmentation: we can slightly distort it, e.g. rescale, to effectively multiply the dataset.

# %% [markdown]
# We will generate rescaled images, minimum - to have smaller dimension equal 256, maximum - 130%. Let's define a function which will do this job:

# %%
# load images from the ML3 folder into torch dataset

image_transform = transforms.Compose([
    transforms.Resize((299, 299)),

    transforms.RandomCrop(512, pad_if_needed=True, fill=255),
    transforms.RandomCrop(299),

    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

dataset = datasets.ImageFolder('ML3', transform=image_transform)

# %%
for im, lbl in dataset:
    print(lbl, im.shape, im.min(), im.max(), im.mean(), im.std())

    # convert tensor to numpy array, transpose from CHW to HWC and scale to range [0, 1]
    im_numpy = im.cpu().numpy().transpose(1,2,0)
    im_numpy -= im_numpy.min(axis=(0,1))
    im_numpy /= im_numpy.max(axis=(0,1))

    plt.figure(figsize=(2,2))
    plt.imshow(im_numpy)
    plt.show()
    break
# Out:
# 0 torch.Size([3, 299, 299]) tensor(-2.0665) tensor(2.6400) tensor(1.8227) tensor(1.1792)

# %%
n_samples = len(dataset)
lbls = np.array([lbl for _, lbl in dataset])

# obtain indeces of training and validation samples
idx_tra, idx_val = train_test_split(np.arange(len(dataset)), test_size=0.2, stratify=lbls)

dataset_tra = torch.utils.data.Subset(dataset, idx_tra)
dataset_val = torch.utils.data.Subset(dataset, idx_val)

# %%
# create data loaders
loader_tra = torch.utils.data.DataLoader(dataset_tra, batch_size=batch_size, shuffle=True)
loader_val = torch.utils.data.DataLoader(dataset_val, batch_size=batch_size, shuffle=False)

# %%
base_model = torch.hub.load('pytorch/vision:v0.7.0', 'inception_v3')

# freeze the parameters of the base model
for param in base_model.parameters():
    param.requires_grad = False

# replace existing fc layer with our 2-layer classication head
in_features = base_model.fc.in_features
n_classes = 2
base_model.fc = fc_head(in_features, n_classes)
model_aug = base_model.to(device)

# Loss function
criterion = nn.CrossEntropyLoss()
# Optimizer
optimizer = optim.Adam(model_aug.parameters(), lr=0.001)
# Out:
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.7.0
# /usr/local/lib/python3.11/dist-packages/torchvision/models/inception.py:43: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn(

# %%
save_path = 'TL_2'

n_epochs=200

history = train_model(model_aug, criterion, optimizer, n_epochs, loader_tra, loader_val, save_path)
# Out:
# Epoch 1/200 | train_loss: 0.7814, train_acc: 0.3500 | val_loss: 0.7423, val_acc: 0.5000
# Epoch 2/200 | train_loss: 0.6460, train_acc: 0.6250 | val_loss: 1.1910, val_acc: 0.5000
# Epoch 3/200 | train_loss: 0.6181, train_acc: 0.7125 | val_loss: 0.9094, val_acc: 0.5000
# Epoch 4/200 | train_loss: 0.6317, train_acc: 0.6125 | val_loss: 0.6719, val_acc: 0.6500
# Epoch 5/200 | train_loss: 0.6179, train_acc: 0.6500 | val_loss: 0.6341, val_acc: 0.7500
# Epoch 6/200 | train_loss: 0.6272, train_acc: 0.6500 | val_loss: 0.6354, val_acc: 0.6000
# Epoch 7/200 | train_loss: 0.6224, train_acc: 0.6250 | val_loss: 0.5622, val_acc: 0.7500
# Epoch 8/200 | train_loss: 0.6346, train_acc: 0.6500 | val_loss: 0.5074, val_acc: 0.8500
# Epoch 9/200 | train_loss: 0.6247, train_acc: 0.6375 | val_loss: 0.5539, val_acc: 0.6500
# Epoch 10/200 | train_loss: 0.6497, train_acc: 0.6125 | val_loss: 0.5590, val_acc: 0.7000
# Epoch 11/200 | train_loss: 0.5841, train_acc: 0.7000 | val_loss: 0.5785, val_acc: 0.7500
# Epoch 12/200 | train_loss: 0.6382, train_acc: 0.6500 | val_loss: 0.5584, val_acc: 0.7500
# Epoch 13/200 | train_loss: 0.6421, train_acc: 0.6500 | val_loss: 0.6571, val_acc: 0.5500
# Epoch 14/200 | train_loss: 0.6201, train_acc: 0.6500 | val_loss: 0.5830, val_acc: 0.6500
# Epoch 15/200 | train_loss: 0.5838, train_acc: 0.6750 | val_loss: 0.5418, val_acc: 0.8500
# Epoch 16/200 | train_loss: 0.6206, train_acc: 0.6500 | val_loss: 0.5190, val_acc: 0.8000
# Epoch 17/200 | train_loss: 0.5865, train_acc: 0.6750 | val_loss: 0.5757, val_acc: 0.6500
# Epoch 18/200 | train_loss: 0.5751, train_acc: 0.7250 | val_loss: 0.5170, val_acc: 0.8000
# Epoch 19/200 | train_loss: 0.6217, train_acc: 0.6375 | val_loss: 0.5063, val_acc: 0.8000
# Epoch 20/200 | train_loss: 0.6226, train_acc: 0.6625 | val_loss: 0.5201, val_acc: 0.7500
# Epoch 21/200 | train_loss: 0.6396, train_acc: 0.6125 | val_loss: 0.6188, val_acc: 0.6500
# Epoch 22/200 | train_loss: 0.5663, train_acc: 0.7375 | val_loss: 0.5625, val_acc: 0.7500
# Epoch 23/200 | train_loss: 0.6208, train_acc: 0.6875 | val_loss: 0.5520, val_acc: 0.8000
# Epoch 24/200 | train_loss: 0.5734, train_acc: 0.6875 | val_loss: 0.5282, val_acc: 0.8000
# Epoch 25/200 | train_loss: 0.5682, train_acc: 0.6875 | val_loss: 0.5032, val_acc: 0.8000
# Epoch 26/200 | train_loss: 0.5636, train_acc: 0.7125 | val_loss: 0.5907, val_acc: 0.7500
# Epoch 27/200 | train_loss: 0.5718, train_acc: 0.7000 | val_loss: 0.5077, val_acc: 0.8000
# Epoch 28/200 | train_loss: 0.6151, train_acc: 0.6375 | val_loss: 0.5494, val_acc: 0.8500
# Epoch 29/200 | train_loss: 0.6130, train_acc: 0.7375 | val_loss: 0.5026, val_acc: 0.7500
# Epoch 30/200 | train_loss: 0.5969, train_acc: 0.6625 | val_loss: 0.5230, val_acc: 0.8000
# Epoch 31/200 | train_loss: 0.6126, train_acc: 0.7000 | val_loss: 0.5434, val_acc: 0.8000
# Epoch 32/200 | train_loss: 0.5970, train_acc: 0.6875 | val_loss: 0.5674, val_acc: 0.7500
# Epoch 33/200 | train_loss: 0.6107, train_acc: 0.6625 | val_loss: 0.5195, val_acc: 0.8500
# Epoch 34/200 | train_loss: 0.5691, train_acc: 0.6875 | val_loss: 0.5639, val_acc: 0.8000
# Epoch 35/200 | train_loss: 0.6258, train_acc: 0.6750 | val_loss: 0.5494, val_acc: 0.7000
# Epoch 36/200 | train_loss: 0.5861, train_acc: 0.6500 | val_loss: 0.5259, val_acc: 0.8000
# Epoch 37/200 | train_loss: 0.6194, train_acc: 0.6750 | val_loss: 0.5092, val_acc: 0.7500
# Epoch 38/200 | train_loss: 0.5835, train_acc: 0.6750 | val_loss: 0.5181, val_acc: 0.8500
# Epoch 39/200 | train_loss: 0.5948, train_acc: 0.7125 | val_loss: 0.4978, val_acc: 0.8500
# Epoch 40/200 | train_loss: 0.5995, train_acc: 0.7125 | val_loss: 0.5846, val_acc: 0.7000
# Epoch 41/200 | train_loss: 0.5709, train_acc: 0.7500 | val_loss: 0.4910, val_acc: 0.8500
# Epoch 42/200 | train_loss: 0.5568, train_acc: 0.7250 | val_loss: 0.5823, val_acc: 0.6500
# Epoch 43/200 | train_loss: 0.5860, train_acc: 0.7000 | val_loss: 0.5409, val_acc: 0.7000
# Epoch 44/200 | train_loss: 0.5614, train_acc: 0.7125 | val_loss: 0.5372, val_acc: 0.8000
# Epoch 45/200 | train_loss: 0.5951, train_acc: 0.6250 | val_loss: 0.5568, val_acc: 0.8000
# Epoch 46/200 | train_loss: 0.5539, train_acc: 0.7375 | val_loss: 0.5315, val_acc: 0.8000
# Epoch 47/200 | train_loss: 0.6170, train_acc: 0.6375 | val_loss: 0.5609, val_acc: 0.7000
# Epoch 48/200 | train_loss: 0.5654, train_acc: 0.7500 | val_loss: 0.5115, val_acc: 0.7500
# Epoch 49/200 | train_loss: 0.5597, train_acc: 0.7375 | val_loss: 0.5389, val_acc: 0.7500
# Epoch 50/200 | train_loss: 0.5121, train_acc: 0.7750 | val_loss: 0.4742, val_acc: 0.8500
# Epoch 51/200 | train_loss: 0.6018, train_acc: 0.7125 | val_loss: 0.5305, val_acc: 0.8000
# Epoch 52/200 | train_loss: 0.5433, train_acc: 0.7125 | val_loss: 0.5292, val_acc: 0.7500
# Epoch 53/200 | train_loss: 0.5580, train_acc: 0.7125 | val_loss: 0.4640, val_acc: 0.8000
# Epoch 54/200 | train_loss: 0.6126, train_acc: 0.7000 | val_loss: 0.5275, val_acc: 0.7000
# Epoch 55/200 | train_loss: 0.5848, train_acc: 0.6875 | val_loss: 0.4887, val_acc: 0.8500
# Epoch 56/200 | train_loss: 0.6445, train_acc: 0.6500 | val_loss: 0.4935, val_acc: 0.8500
# Epoch 57/200 | train_loss: 0.6043, train_acc: 0.7125 | val_loss: 0.4857, val_acc: 0.8000
# Epoch 58/200 | train_loss: 0.5665, train_acc: 0.7000 | val_loss: 0.5592, val_acc: 0.8000
# Epoch 59/200 | train_loss: 0.5865, train_acc: 0.6875 | val_loss: 0.5353, val_acc: 0.8000
# Epoch 60/200 | train_loss: 0.5935, train_acc: 0.7000 | val_loss: 0.5199, val_acc: 0.7500
# Epoch 61/200 | train_loss: 0.5660, train_acc: 0.7000 | val_loss: 0.5172, val_acc: 0.8000
# Epoch 62/200 | train_loss: 0.6059, train_acc: 0.6750 | val_loss: 0.5094, val_acc: 0.8000
# Epoch 63/200 | train_loss: 0.5624, train_acc: 0.7875 | val_loss: 0.4767, val_acc: 0.8500
# Epoch 64/200 | train_loss: 0.5244, train_acc: 0.7375 | val_loss: 0.5787, val_acc: 0.6500
# Epoch 65/200 | train_loss: 0.5506, train_acc: 0.7250 | val_loss: 0.5617, val_acc: 0.6500
# Epoch 66/200 | train_loss: 0.5843, train_acc: 0.7125 | val_loss: 0.5446, val_acc: 0.8000
# Epoch 67/200 | train_loss: 0.5317, train_acc: 0.7250 | val_loss: 0.5314, val_acc: 0.8000
# Epoch 68/200 | train_loss: 0.5166, train_acc: 0.7625 | val_loss: 0.4666, val_acc: 0.8500
# Epoch 69/200 | train_loss: 0.6109, train_acc: 0.6625 | val_loss: 0.5173, val_acc: 0.8000
# Epoch 70/200 | train_loss: 0.5753, train_acc: 0.6375 | val_loss: 0.4490, val_acc: 0.8500
# Epoch 71/200 | train_loss: 0.5561, train_acc: 0.6750 | val_loss: 0.5639, val_acc: 0.8000
# Epoch 72/200 | train_loss: 0.5683, train_acc: 0.7000 | val_loss: 0.5071, val_acc: 0.8500
# Epoch 73/200 | train_loss: 0.5470, train_acc: 0.6875 | val_loss: 0.5097, val_acc: 0.8500
# Epoch 74/200 | train_loss: 0.6241, train_acc: 0.6250 | val_loss: 0.5138, val_acc: 0.7000
# Epoch 75/200 | train_loss: 0.5859, train_acc: 0.6875 | val_loss: 0.5023, val_acc: 0.8000
# Epoch 76/200 | train_loss: 0.6200, train_acc: 0.6625 | val_loss: 0.5436, val_acc: 0.7500
# Epoch 77/200 | train_loss: 0.5440, train_acc: 0.7625 | val_loss: 0.5254, val_acc: 0.8000
# Epoch 78/200 | train_loss: 0.5937, train_acc: 0.6750 | val_loss: 0.5380, val_acc: 0.8000
# Epoch 79/200 | train_loss: 0.5423, train_acc: 0.7250 | val_loss: 0.5017, val_acc: 0.8500
# Epoch 80/200 | train_loss: 0.6283, train_acc: 0.6250 | val_loss: 0.5336, val_acc: 0.8000
# Epoch 81/200 | train_loss: 0.5473, train_acc: 0.7625 | val_loss: 0.4521, val_acc: 0.8000
# Epoch 82/200 | train_loss: 0.5413, train_acc: 0.7250 | val_loss: 0.4859, val_acc: 0.8000
# Epoch 83/200 | train_loss: 0.5558, train_acc: 0.7375 | val_loss: 0.5646, val_acc: 0.7500
# Epoch 84/200 | train_loss: 0.6153, train_acc: 0.6750 | val_loss: 0.5047, val_acc: 0.8500
# Epoch 85/200 | train_loss: 0.5542, train_acc: 0.7250 | val_loss: 0.5330, val_acc: 0.8000
# Epoch 86/200 | train_loss: 0.5727, train_acc: 0.7250 | val_loss: 0.5423, val_acc: 0.8500
# Epoch 87/200 | train_loss: 0.4946, train_acc: 0.7250 | val_loss: 0.4867, val_acc: 0.8500
# Epoch 88/200 | train_loss: 0.5976, train_acc: 0.6625 | val_loss: 0.5130, val_acc: 0.8500
# Epoch 89/200 | train_loss: 0.5485, train_acc: 0.6750 | val_loss: 0.5479, val_acc: 0.8000
# Epoch 90/200 | train_loss: 0.5435, train_acc: 0.7500 | val_loss: 0.5027, val_acc: 0.8000
# Epoch 91/200 | train_loss: 0.6287, train_acc: 0.6375 | val_loss: 0.5099, val_acc: 0.8000
# Epoch 92/200 | train_loss: 0.6763, train_acc: 0.5750 | val_loss: 0.5661, val_acc: 0.7000
# Epoch 93/200 | train_loss: 0.5441, train_acc: 0.7250 | val_loss: 0.5348, val_acc: 0.7000
# Epoch 94/200 | train_loss: 0.5689, train_acc: 0.6750 | val_loss: 0.4825, val_acc: 0.8000
# Epoch 95/200 | train_loss: 0.6054, train_acc: 0.6750 | val_loss: 0.4922, val_acc: 0.8500
# Epoch 96/200 | train_loss: 0.5625, train_acc: 0.6750 | val_loss: 0.5042, val_acc: 0.7500
# Epoch 97/200 | train_loss: 0.6069, train_acc: 0.6625 | val_loss: 0.5758, val_acc: 0.5500
# Epoch 98/200 | train_loss: 0.5480, train_acc: 0.7250 | val_loss: 0.5135, val_acc: 0.8000
# Epoch 99/200 | train_loss: 0.5399, train_acc: 0.7500 | val_loss: 0.5420, val_acc: 0.8500
# Epoch 100/200 | train_loss: 0.5764, train_acc: 0.7125 | val_loss: 0.5249, val_acc: 0.7500
# Epoch 101/200 | train_loss: 0.5348, train_acc: 0.7125 | val_loss: 0.5221, val_acc: 0.8500
# Epoch 102/200 | train_loss: 0.5099, train_acc: 0.7500 | val_loss: 0.4835, val_acc: 0.7500
# Epoch 103/200 | train_loss: 0.5408, train_acc: 0.7625 | val_loss: 0.5638, val_acc: 0.7500
# Epoch 104/200 | train_loss: 0.6308, train_acc: 0.6500 | val_loss: 0.5855, val_acc: 0.5500
# Epoch 105/200 | train_loss: 0.5946, train_acc: 0.7125 | val_loss: 0.5448, val_acc: 0.7500
# Epoch 106/200 | train_loss: 0.5406, train_acc: 0.7250 | val_loss: 0.5123, val_acc: 0.8000
# Epoch 107/200 | train_loss: 0.5812, train_acc: 0.6500 | val_loss: 0.4442, val_acc: 0.8500
# Epoch 108/200 | train_loss: 0.5053, train_acc: 0.7625 | val_loss: 0.6244, val_acc: 0.7000
# Epoch 109/200 | train_loss: 0.5813, train_acc: 0.6875 | val_loss: 0.5264, val_acc: 0.8500
# Epoch 110/200 | train_loss: 0.5557, train_acc: 0.7375 | val_loss: 0.4626, val_acc: 0.9000
# Epoch 111/200 | train_loss: 0.5799, train_acc: 0.7000 | val_loss: 0.5490, val_acc: 0.8000
# Epoch 112/200 | train_loss: 0.5535, train_acc: 0.7250 | val_loss: 0.5081, val_acc: 0.7500
# Epoch 113/200 | train_loss: 0.5280, train_acc: 0.7500 | val_loss: 0.5292, val_acc: 0.8000
# Epoch 114/200 | train_loss: 0.5144, train_acc: 0.7750 | val_loss: 0.5242, val_acc: 0.8500
# Epoch 115/200 | train_loss: 0.5374, train_acc: 0.7750 | val_loss: 0.4039, val_acc: 0.8500
# Epoch 116/200 | train_loss: 0.5039, train_acc: 0.7500 | val_loss: 0.4641, val_acc: 0.7500
# Epoch 117/200 | train_loss: 0.6504, train_acc: 0.6125 | val_loss: 0.5127, val_acc: 0.8000
# Epoch 118/200 | train_loss: 0.5577, train_acc: 0.7375 | val_loss: 0.4553, val_acc: 0.8500
# Epoch 119/200 | train_loss: 0.6005, train_acc: 0.7125 | val_loss: 0.5225, val_acc: 0.8000
# Epoch 120/200 | train_loss: 0.5318, train_acc: 0.7500 | val_loss: 0.5089, val_acc: 0.7500
# Epoch 121/200 | train_loss: 0.5379, train_acc: 0.6875 | val_loss: 0.4785, val_acc: 0.8500
# Epoch 122/200 | train_loss: 0.6049, train_acc: 0.6500 | val_loss: 0.4116, val_acc: 0.9000
# Epoch 123/200 | train_loss: 0.5281, train_acc: 0.7125 | val_loss: 0.4754, val_acc: 0.8000
# Epoch 124/200 | train_loss: 0.5428, train_acc: 0.7375 | val_loss: 0.4746, val_acc: 0.8500
# Epoch 125/200 | train_loss: 0.5568, train_acc: 0.7125 | val_loss: 0.4706, val_acc: 0.7500
# Epoch 126/200 | train_loss: 0.5693, train_acc: 0.7125 | val_loss: 0.5647, val_acc: 0.7500
# Epoch 127/200 | train_loss: 0.5811, train_acc: 0.6875 | val_loss: 0.4809, val_acc: 0.8500
# Epoch 128/200 | train_loss: 0.5664, train_acc: 0.7000 | val_loss: 0.4872, val_acc: 0.8500
# Epoch 129/200 | train_loss: 0.5292, train_acc: 0.7000 | val_loss: 0.4584, val_acc: 0.8500
# Epoch 130/200 | train_loss: 0.5354, train_acc: 0.7000 | val_loss: 0.5424, val_acc: 0.8500
# Epoch 131/200 | train_loss: 0.5086, train_acc: 0.7375 | val_loss: 0.4993, val_acc: 0.7500
# Epoch 132/200 | train_loss: 0.5397, train_acc: 0.7375 | val_loss: 0.4717, val_acc: 0.8000
# Epoch 133/200 | train_loss: 0.5164, train_acc: 0.7375 | val_loss: 0.4809, val_acc: 0.8500
# Epoch 134/200 | train_loss: 0.5855, train_acc: 0.6625 | val_loss: 0.4401, val_acc: 0.8500
# Epoch 135/200 | train_loss: 0.6003, train_acc: 0.6500 | val_loss: 0.5357, val_acc: 0.8500
# Epoch 136/200 | train_loss: 0.5379, train_acc: 0.7125 | val_loss: 0.5171, val_acc: 0.8000
# Epoch 137/200 | train_loss: 0.5263, train_acc: 0.7375 | val_loss: 0.5124, val_acc: 0.7000
# Epoch 138/200 | train_loss: 0.5801, train_acc: 0.7000 | val_loss: 0.4392, val_acc: 0.8500
# Epoch 139/200 | train_loss: 0.5424, train_acc: 0.7250 | val_loss: 0.4938, val_acc: 0.8000
# Epoch 140/200 | train_loss: 0.5831, train_acc: 0.6750 | val_loss: 0.5056, val_acc: 0.8000
# Epoch 141/200 | train_loss: 0.4968, train_acc: 0.7500 | val_loss: 0.4840, val_acc: 0.7000
# Epoch 142/200 | train_loss: 0.5284, train_acc: 0.7125 | val_loss: 0.4717, val_acc: 0.8500
# Epoch 143/200 | train_loss: 0.5204, train_acc: 0.7125 | val_loss: 0.4677, val_acc: 0.7500
# Epoch 144/200 | train_loss: 0.5217, train_acc: 0.7375 | val_loss: 0.4989, val_acc: 0.8500
# Epoch 145/200 | train_loss: 0.6215, train_acc: 0.6750 | val_loss: 0.4618, val_acc: 0.8500
# Epoch 146/200 | train_loss: 0.5085, train_acc: 0.7750 | val_loss: 0.4495, val_acc: 0.8000
# Epoch 147/200 | train_loss: 0.6308, train_acc: 0.6000 | val_loss: 0.5320, val_acc: 0.8000
# Epoch 148/200 | train_loss: 0.5869, train_acc: 0.6750 | val_loss: 0.5318, val_acc: 0.8000
# Epoch 149/200 | train_loss: 0.5399, train_acc: 0.7750 | val_loss: 0.5563, val_acc: 0.8000
# Epoch 150/200 | train_loss: 0.5945, train_acc: 0.6125 | val_loss: 0.5138, val_acc: 0.8000
# Epoch 151/200 | train_loss: 0.6120, train_acc: 0.6875 | val_loss: 0.6351, val_acc: 0.7000
# Epoch 152/200 | train_loss: 0.5679, train_acc: 0.6875 | val_loss: 0.4901, val_acc: 0.8500
# Epoch 153/200 | train_loss: 0.5639, train_acc: 0.7375 | val_loss: 0.5115, val_acc: 0.7500
# Epoch 154/200 | train_loss: 0.5432, train_acc: 0.7250 | val_loss: 0.4915, val_acc: 0.8000
# Epoch 155/200 | train_loss: 0.5671, train_acc: 0.7000 | val_loss: 0.5118, val_acc: 0.8000
# Epoch 156/200 | train_loss: 0.5107, train_acc: 0.7500 | val_loss: 0.4813, val_acc: 0.8500
# Epoch 157/200 | train_loss: 0.4956, train_acc: 0.8000 | val_loss: 0.5374, val_acc: 0.7000
# Epoch 158/200 | train_loss: 0.6156, train_acc: 0.7125 | val_loss: 0.4862, val_acc: 0.8000
# Epoch 159/200 | train_loss: 0.5268, train_acc: 0.7250 | val_loss: 0.5246, val_acc: 0.8000
# Epoch 160/200 | train_loss: 0.4912, train_acc: 0.7500 | val_loss: 0.4812, val_acc: 0.8500
# Epoch 161/200 | train_loss: 0.5133, train_acc: 0.7750 | val_loss: 0.4884, val_acc: 0.7500
# Epoch 162/200 | train_loss: 0.4819, train_acc: 0.7625 | val_loss: 0.4430, val_acc: 0.8000
# Epoch 163/200 | train_loss: 0.5658, train_acc: 0.7125 | val_loss: 0.5697, val_acc: 0.7500
# Epoch 164/200 | train_loss: 0.5645, train_acc: 0.7000 | val_loss: 0.4258, val_acc: 0.8500
# Epoch 165/200 | train_loss: 0.5373, train_acc: 0.7500 | val_loss: 0.4694, val_acc: 0.8000
# Epoch 166/200 | train_loss: 0.5421, train_acc: 0.7125 | val_loss: 0.4990, val_acc: 0.7500
# Epoch 167/200 | train_loss: 0.6126, train_acc: 0.6875 | val_loss: 0.5681, val_acc: 0.8500
# Epoch 168/200 | train_loss: 0.5798, train_acc: 0.7000 | val_loss: 0.4626, val_acc: 0.8500
# Epoch 169/200 | train_loss: 0.5543, train_acc: 0.7250 | val_loss: 0.5164, val_acc: 0.8500
# Epoch 170/200 | train_loss: 0.5530, train_acc: 0.7375 | val_loss: 0.4994, val_acc: 0.7500
# Epoch 171/200 | train_loss: 0.4754, train_acc: 0.8125 | val_loss: 0.4775, val_acc: 0.8000
# Epoch 172/200 | train_loss: 0.5326, train_acc: 0.7750 | val_loss: 0.4962, val_acc: 0.8000
# Epoch 173/200 | train_loss: 0.5029, train_acc: 0.7625 | val_loss: 0.5043, val_acc: 0.8000
# Epoch 174/200 | train_loss: 0.5124, train_acc: 0.8250 | val_loss: 0.5116, val_acc: 0.8000
# Epoch 175/200 | train_loss: 0.5394, train_acc: 0.7125 | val_loss: 0.4482, val_acc: 0.8500
# Epoch 176/200 | train_loss: 0.5647, train_acc: 0.7250 | val_loss: 0.4696, val_acc: 0.7500
# Epoch 177/200 | train_loss: 0.5214, train_acc: 0.7875 | val_loss: 0.4560, val_acc: 0.7500
# Epoch 178/200 | train_loss: 0.5035, train_acc: 0.7875 | val_loss: 0.4943, val_acc: 0.8500
# Epoch 179/200 | train_loss: 0.5542, train_acc: 0.6625 | val_loss: 0.4424, val_acc: 0.8500
# Epoch 180/200 | train_loss: 0.5400, train_acc: 0.7125 | val_loss: 0.5301, val_acc: 0.8500
# Epoch 181/200 | train_loss: 0.5806, train_acc: 0.7250 | val_loss: 0.6242, val_acc: 0.7500
# Epoch 182/200 | train_loss: 0.5691, train_acc: 0.6875 | val_loss: 0.6012, val_acc: 0.6000
# Epoch 183/200 | train_loss: 0.6011, train_acc: 0.6875 | val_loss: 0.5308, val_acc: 0.7500
# Epoch 184/200 | train_loss: 0.5990, train_acc: 0.6875 | val_loss: 0.5173, val_acc: 0.8000
# Epoch 185/200 | train_loss: 0.4962, train_acc: 0.7375 | val_loss: 0.5188, val_acc: 0.8000
# Epoch 186/200 | train_loss: 0.5284, train_acc: 0.7250 | val_loss: 0.4750, val_acc: 0.8500
# Epoch 187/200 | train_loss: 0.5525, train_acc: 0.6750 | val_loss: 0.4677, val_acc: 0.7500
# Epoch 188/200 | train_loss: 0.5673, train_acc: 0.7125 | val_loss: 0.5239, val_acc: 0.8500
# Epoch 189/200 | train_loss: 0.5059, train_acc: 0.7250 | val_loss: 0.5238, val_acc: 0.8000
# Epoch 190/200 | train_loss: 0.5833, train_acc: 0.7000 | val_loss: 0.4294, val_acc: 0.9000
# Epoch 191/200 | train_loss: 0.5107, train_acc: 0.7375 | val_loss: 0.4458, val_acc: 0.8500
# Epoch 192/200 | train_loss: 0.5710, train_acc: 0.7375 | val_loss: 0.5063, val_acc: 0.8000
# Epoch 193/200 | train_loss: 0.5987, train_acc: 0.7125 | val_loss: 0.4852, val_acc: 0.7500
# Epoch 194/200 | train_loss: 0.5445, train_acc: 0.7000 | val_loss: 0.5189, val_acc: 0.8000
# Epoch 195/200 | train_loss: 0.5221, train_acc: 0.7625 | val_loss: 0.5758, val_acc: 0.8000
# Epoch 196/200 | train_loss: 0.5568, train_acc: 0.7000 | val_loss: 0.5324, val_acc: 0.8000
# Epoch 197/200 | train_loss: 0.5761, train_acc: 0.7000 | val_loss: 0.5100, val_acc: 0.8500
# Epoch 198/200 | train_loss: 0.5031, train_acc: 0.7625 | val_loss: 0.5043, val_acc: 0.7500
# Epoch 199/200 | train_loss: 0.4978, train_acc: 0.7375 | val_loss: 0.4698, val_acc: 0.8500
# Epoch 200/200 | train_loss: 0.5980, train_acc: 0.7375 | val_loss: 0.4892, val_acc: 0.7500

# %%
plot_history(history)

# %% [markdown]
# We had a REEEALLY small dataset for such a complicated task. Does it really generalize? mb it just memorizes all the images we fed into it? Lets perform a test. `w1.PNG` and `w2.PNG` are text screenshots from wikipedia in [Italian](https://it.wikipedia.org/wiki/Apprendimento_automatico) and [German](https://de.wikipedia.org/wiki/Maschinelles_Lernen).

# %% [markdown]
# ## 9. Exersize 1

# %%
# load images
im_wiki_1 = plt.imread('ML3/w1.jpg')
im_wiki_2 = plt.imread('ML3/w2.jpg')

# %% [markdown]
# visualize the samples and perform inference

# %%
im_wiki_1
# Out:
# tensor([[[[ 2.2489,  2.2489,  2.2489,  ...,  2.2489,  2.2489,  2.2489],
#           [ 2.2489,  2.2489,  2.2489,  ...,  2.2489,  2.2489,  2.2489],
#           [ 2.2489,  2.2489,  2.2489,  ...,  2.2489,  2.2489,  2.2489],
#           ...,
#           [ 2.2489,  2.2489,  2.2489,  ...,  2.2489,  2.2489,  2.2489],
#           [ 2.2489,  2.2489,  2.2489,  ...,  2.1119,  2.1633,  2.2489],
#           [ 2.2489,  2.2489,  2.2489,  ...,  1.3070,  1.6324,  2.2489]],
#
#          [[ 2.4286,  2.4286,  2.4286,  ...,  2.4286,  2.4286,  2.4286],
#           [ 2.4286,  2.4286,  2.4286,  ...,  2.4286,  2.4286,  2.4286],
#           [ 2.4286,  2.4286,  2.4286,  ...,  2.4286,  2.4286,  2.4286],
#           ...,
#           [ 2.4286,  2.4286,  2.4286,  ...,  2.4286,  2.4286,  2.4286],
#           [ 2.4286,  2.4286,  2.4286,  ...,  1.9559,  2.3410,  2.4286],
#           [ 2.4286,  2.4286,  2.4286,  ..., -0.8627,  1.8683,  2.4286]],
#
#          [[ 2.6400,  2.6400,  2.6400,  ...,  2.6400,  2.6400,  2.6400],
#           [ 2.6400,  2.6400,  2.6400,  ...,  2.6400,  2.6400,  2.6400],
#           [ 2.6400,  2.6400,  2.6400,  ...,  2.6400,  2.6400,  2.6400],
#           ...,
#           [ 2.6400,  2.6400,  2.6400,  ...,  2.6400,  2.6400,  2.6400],
#           [ 2.6400,  2.6400,  2.6400,  ...,  2.1520,  2.6400,  2.6400],
#           [ 2.6400,  2.6400,  2.6400,  ..., -0.7413,  2.6400,  2.6400]]]],
#        device='cuda:0')

# %%
    im_wiki_2 = Image.open('ML3/w2.jpg')
    im_wiki_2 = image_transform(im_wiki_2)
    im = im_wiki_2

    print(im.shape, im.min(), im.max(), im.mean(), im.std())

    # convert tensor to numpy array, transpose from CHW to HWC and scale to range [0, 1]
    im_numpy = im.cpu().numpy().transpose(1,2,0)
    im_numpy -= im_numpy.min(axis=(0,1))
    im_numpy /= im_numpy.max(axis=(0,1))

    plt.figure(figsize=(5,5))
    plt.imshow(im_numpy)
    plt.show()
# Out:
# torch.Size([3, 299, 299]) tensor(-1.4672) tensor(2.6400) tensor(2.3474) tensor(0.4531)

# %%
im_wiki_1 = Image.open('ML3/w1.jpg')
im_wiki_1 = image_transform(im_wiki_1)
im_wiki_1 = im_wiki_1.unsqueeze(0).to(device) # unsqueeze(0) adds the batch dimension or else it will be missing a dimension

im_wiki_2 = Image.open('ML3/w2.jpg')
im_wiki_2 = image_transform(im_wiki_2)
im_wiki_2 = im_wiki_2.unsqueeze(0).to(device)


def perform_interference(im_tensor):
  with torch.no_grad():
    logits = model_aug(im_tensor)
    probs = F.softmax(logits, dim = 1)
    pred = torch.argmax(logits, dim = 1)


  probs = probs.cpu().numpy()[0]
  pred = pred.cpu().numpy()[0]
  print(f"Probability: {probs[pred]}, Prediction: {text_label[pred]}")

perform_interference(im_wiki_1)
perform_interference(im_wiki_2)
# Out:
# Probability: 0.9381901025772095, Prediction: it
# Probability: 0.6845865845680237, Prediction: it

# %%
image_transform = transforms.Compose([
    transforms.Resize((299, 299)),

    #transforms.RandomCrop(512, pad_if_needed=True, fill=255),
    #transforms.RandomCrop(299),

    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %% [markdown]
# ## 10. Excercises

# %% [markdown]
# Do in 4 groups (35 min), in the end present results (2 min/group)

# %% [markdown]
# ### Option 1.

# %% [markdown]
# In the situation when the model is likely to overfit, final performance would especially depend on the training datasets variety.
#
# * Experiment with changes in aspect ratio and scale, using, e.g.
#   `transforms.RandomResizedCrop(299, scale=(0.5, 2.0), ratio=(0.7, 1.3))` instead of the `transforms.RandomCrop`.
# * Which other augmentations would make sense for the text data?
# * Experiment and compare resulting best validation performance and number of epochs until the best validation accuracy.

# %% [markdown]
# ### Option 2.

# %% [markdown]
# In the situation when the model is likely to overfit, final performance would especially depend on the learning rate.
#
# * Plot the best validation accuracy vs learning rate.
# * Plot the number of epochs until the best validation accuracy vs learning rate.
#
# Test learning rates within +/- 1.5 orders of magnitude, i.e. from 30 times smaller to 30 times larger learning rates, than the current one.
#
# Get 3 replicates.

# %% [markdown]
# ### Option 3.

# %% [markdown]
# In the situation when the model is likely to overfit, final performance would especially depend on the model's architecture.
#
# * Plot the best validation accuracy vs width of the first dense layer.
# * Plot the number of epochs until the best validation accuracy vs width.
#
# Test number of features in the first dense layer between 8 and 4096.
#
# Get 3 replicates.

# %% [markdown]
# ### Option 4.

# %% [markdown]
# We tested one model for the backbone of transfer learning. Try other ones (at least 3): https://pytorch.org/vision/stable/models.html.
#
#
# * Plot the best validation accuracy vs model.
# * Plot the number of epochs until the best validation accuracy vs model.
# * Does any model generalize to wiki data?
#
# Run 3 replicates for each model. Input size might vary for different models, adjust the crop size accordingly in parameters to `prepare_training_img`.
