# %% [markdown]
# ## Tutorial II: Optimization in **pytorch** and NN introduction
#
# <p>
# Bern Winter School on Machine Learning, 2024<br>
# Prepared by Mykhailo Vladymyrov and Matthew Vowels.
# </p>
#
# This work is licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.

# %%
# time to teach without exercises 50mins

# %% [markdown]
# ## 1. Load necessary libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %% [markdown]
# ## 2. Linear fit
#
# Here we will solve optimization problem to perform linear regression. First we will generate training set of 80 data points and test set of 20, laying on a line with a random offset $$y = a_0 x + b_0 + \delta,$$ where $\delta$ is a random variable sampled from a uniform distribution with standard deviation equal to $s_0$.
# <!-- o.f.: 46, 48, 87, 99 | val better than train: 47, 56, 86. -->

# %%
a0 = 3  # 3
b0 = 5  # 5
s0 = 5  # 1

n_all = 100

np.random.seed(99)

# all samples
x_all = np.linspace(0, 10, n_all)  # 100 points
d_all = np.random.uniform(-s0, s0, size=n_all)
y_all = np.asarray([a0*x + b0 + d for x, d in zip(x_all, d_all)])

# randomize order and get 80% for training
idx = np.random.permutation(n_all)
n_train = n_all * 80 // 100

idx_train = idx[0:n_train]
idx_val = idx[n_train:]

x_train, y_train = x_all[idx_train], y_all[idx_train]

x_val, y_val = x_all[idx_val], y_all[idx_val]

plt.plot(x_train, y_train, "or", x_val, y_val, "b^")
plt.legend(('training points', 'validation points'),  loc='upper left');

# %% [markdown]
# We will then define loss function as the mean of squared residuals (distance from line along $y$) for the points.
#
# We will use [stochactic gradient descent](https://en.wikipedia.org/wiki/Stochastic_gradient_descent): on each iteration use only a fraction (`batch_size`) of all training set. In many cases training set is huge and cannot be fed on each iteration in principle. Also it can sometimes help the optimizer to properly explore the manifold.

# %%
class Linear(nn.Module):
    def __init__(self):
        super(Linear, self).__init__()
        self.a = nn.Parameter(torch.randn(1, requires_grad=True))
        self.b = nn.Parameter(torch.randn(1, requires_grad=True))

    def forward(self, x):
        return self.a * x + self.b


def loss_f(true_y, y_predicted):
    return F.mse_loss(y_predicted, true_y)

# %%
len(x_train)
# Out:
# 80

# %%
# Define the model
model = Linear()

# Define the optimizer
optimizer = optim.SGD(model.parameters(), lr=0.002) # apparently lr = 0.002 is a good starting point for it

# Define the number of epochs and batch size
epochs = 400
batch_size = 10


x_train = torch.tensor(x_train)  # watch out for d-type issues with torch.tensors
y_train = torch.tensor(y_train)

x_val = torch.tensor(x_val)
y_val = torch.tensor(y_val)



# Training loop
train_loss_history = []
val_loss_history = []
for epoch in range(epochs):
    model.train()  # as opposed to model.eval()
    batch_losses = []
    permutation = torch.randperm(x_train.size()[0])


    for i in range(0, x_train.size()[0], batch_size): # running on these batches optimizes the performance of the loss function, because instead of doing it on the whole data set all the time you take these smaller batches
        optimizer.zero_grad()

        indices = permutation[i:i+batch_size]
        batch_x, batch_y = x_train[indices], y_train[indices]

        # Forward pass
        outputs = model(batch_x)

        # Compute the loss
        loss = loss_f(batch_y, outputs)
        batch_losses.append(loss.item())
        # Backward pass and optimization
        loss.backward()
        optimizer.step()

    average_training_loss = np.mean(batch_losses)
    train_loss_history.append(average_training_loss)

    # Validation step (optional, for monitoring performance)
    model.eval() #evalute the model
    with torch.no_grad():
        val_outputs = model(x_val)
        val_loss = loss_f(y_val, val_outputs)
        val_loss_history.append(val_loss)
        print(f"Epoch {epoch+1}/{epochs}, Validation Loss: {val_loss.item()}")
# Out:
# Epoch 1/400, Validation Loss: 80.73224369899619
# Epoch 2/400, Validation Loss: 17.67199833895594
# Epoch 3/400, Validation Loss: 12.493382430978738
# Epoch 4/400, Validation Loss: 12.450984115456835
# Epoch 5/400, Validation Loss: 12.513457964527097
# Epoch 6/400, Validation Loss: 12.572127651149206
# Epoch 7/400, Validation Loss: 12.502300141485138
# Epoch 8/400, Validation Loss: 12.481638453991449
# Epoch 9/400, Validation Loss: 12.575723478767548
# Epoch 10/400, Validation Loss: 12.447345582314213
# Epoch 11/400, Validation Loss: 12.199319631032926
# Epoch 12/400, Validation Loss: 12.241453879910285
# Epoch 13/400, Validation Loss: 12.120249379164695
# Epoch 14/400, Validation Loss: 12.116150247495417
# Epoch 15/400, Validation Loss: 12.100925097085751
# Epoch 16/400, Validation Loss: 12.021939689659956
# Epoch 17/400, Validation Loss: 11.825123786535803
# Epoch 18/400, Validation Loss: 11.947804322838547
# Epoch 19/400, Validation Loss: 11.950420386703051
# Epoch 20/400, Validation Loss: 11.82389123588985
# Epoch 21/400, Validation Loss: 11.886347949147341
# Epoch 22/400, Validation Loss: 11.836024889466163
# Epoch 23/400, Validation Loss: 11.60951181110425
# Epoch 24/400, Validation Loss: 11.68108874199577
# Epoch 25/400, Validation Loss: 11.541863892674579
# Epoch 26/400, Validation Loss: 11.62150822985253
# Epoch 27/400, Validation Loss: 11.450505365303403
# Epoch 28/400, Validation Loss: 11.45634822774125
# Epoch 29/400, Validation Loss: 11.562887234066242
# Epoch 30/400, Validation Loss: 11.428044959044504
# Epoch 31/400, Validation Loss: 11.313564762695602
# Epoch 32/400, Validation Loss: 11.513449105672503
# Epoch 33/400, Validation Loss: 11.331626072817878
# Epoch 34/400, Validation Loss: 11.267605926909914
# Epoch 35/400, Validation Loss: 11.182218052778476
# Epoch 36/400, Validation Loss: 11.125509858523825
# Epoch 37/400, Validation Loss: 11.37982517095983
# Epoch 38/400, Validation Loss: 11.1930546831665
# Epoch 39/400, Validation Loss: 10.995158904144688
# Epoch 40/400, Validation Loss: 11.047317373497595
# Epoch 41/400, Validation Loss: 11.152181569667937
# Epoch 42/400, Validation Loss: 11.362016330354953
# Epoch 43/400, Validation Loss: 11.147685740531514
# Epoch 44/400, Validation Loss: 11.011878053686118
# Epoch 45/400, Validation Loss: 11.087075344314194
# Epoch 46/400, Validation Loss: 11.141343016045804
# Epoch 47/400, Validation Loss: 11.018046499936233
# Epoch 48/400, Validation Loss: 11.05201185439523
# Epoch 49/400, Validation Loss: 10.806118414987358
# Epoch 50/400, Validation Loss: 10.856684704564412
# Epoch 51/400, Validation Loss: 10.857148947844355
# Epoch 52/400, Validation Loss: 10.900273952703547
# Epoch 53/400, Validation Loss: 10.829760438002491
# Epoch 54/400, Validation Loss: 10.826439724792646
# Epoch 55/400, Validation Loss: 10.902766763554805
# Epoch 56/400, Validation Loss: 10.746951730712771
# Epoch 57/400, Validation Loss: 10.882722348054386
# Epoch 58/400, Validation Loss: 10.915673358165348
# Epoch 59/400, Validation Loss: 10.816305698000193
# Epoch 60/400, Validation Loss: 10.78492118098435
# Epoch 61/400, Validation Loss: 10.831125849721792
# Epoch 62/400, Validation Loss: 10.799555298325012
# Epoch 63/400, Validation Loss: 10.765035637395595
# Epoch 64/400, Validation Loss: 10.768835269204578
# Epoch 65/400, Validation Loss: 10.650125116647368
# Epoch 66/400, Validation Loss: 10.756157802702159
# Epoch 67/400, Validation Loss: 10.5753274305589
# Epoch 68/400, Validation Loss: 10.62766992462991
# Epoch 69/400, Validation Loss: 10.636794866683864
# Epoch 70/400, Validation Loss: 10.52981802141313
# Epoch 71/400, Validation Loss: 10.536522896550538
# Epoch 72/400, Validation Loss: 10.448113003680003
# Epoch 73/400, Validation Loss: 10.45430563096523
# Epoch 74/400, Validation Loss: 10.476473579398355
# Epoch 75/400, Validation Loss: 10.456993358893694
# Epoch 76/400, Validation Loss: 10.59438634829309
# Epoch 77/400, Validation Loss: 10.463110588654684
# Epoch 78/400, Validation Loss: 10.488071100999752
# Epoch 79/400, Validation Loss: 10.469747437142303
# Epoch 80/400, Validation Loss: 10.43630463397564
# Epoch 81/400, Validation Loss: 10.387765929262438
# Epoch 82/400, Validation Loss: 10.40879628739807
# Epoch 83/400, Validation Loss: 10.473781052706531
# Epoch 84/400, Validation Loss: 10.486538548332362
# Epoch 85/400, Validation Loss: 10.481735664615002
# Epoch 86/400, Validation Loss: 10.44288022264395
# Epoch 87/400, Validation Loss: 10.485440894044114
# Epoch 88/400, Validation Loss: 10.436702679411457
# Epoch 89/400, Validation Loss: 10.390121266254829
# Epoch 90/400, Validation Loss: 10.371655327989824
# Epoch 91/400, Validation Loss: 10.367927006724555
# Epoch 92/400, Validation Loss: 10.278063134049427
# Epoch 93/400, Validation Loss: 10.34521327461734
# Epoch 94/400, Validation Loss: 10.217411809698568
# Epoch 95/400, Validation Loss: 10.36123425320363
# Epoch 96/400, Validation Loss: 10.461207311093888
# Epoch 97/400, Validation Loss: 10.397122086178905
# Epoch 98/400, Validation Loss: 10.276571942968799
# Epoch 99/400, Validation Loss: 10.213484477101035
# Epoch 100/400, Validation Loss: 10.356811386581416
# Epoch 101/400, Validation Loss: 10.29966197533906
# Epoch 102/400, Validation Loss: 10.166274523032694
# Epoch 103/400, Validation Loss: 10.207800106089744
# Epoch 104/400, Validation Loss: 10.305916594052349
# Epoch 105/400, Validation Loss: 10.361568864251094
# Epoch 106/400, Validation Loss: 10.395853184998789
# Epoch 107/400, Validation Loss: 10.455118880072703
# Epoch 108/400, Validation Loss: 10.48196942309482
# Epoch 109/400, Validation Loss: 10.460468844584069
# Epoch 110/400, Validation Loss: 10.458088185682499
# Epoch 111/400, Validation Loss: 10.312723579073994
# Epoch 112/400, Validation Loss: 10.400048515734472
# Epoch 113/400, Validation Loss: 10.369434762205774
# Epoch 114/400, Validation Loss: 10.275306064259748
# Epoch 115/400, Validation Loss: 10.233884133686717
# Epoch 116/400, Validation Loss: 10.2091918491241
# Epoch 117/400, Validation Loss: 10.199229623924863
# Epoch 118/400, Validation Loss: 10.135404017710117
# Epoch 119/400, Validation Loss: 10.339840663521072
# Epoch 120/400, Validation Loss: 10.3133502769568
# Epoch 121/400, Validation Loss: 10.309692926031591
# Epoch 122/400, Validation Loss: 10.329736001004749
# Epoch 123/400, Validation Loss: 10.162060629760488
# Epoch 124/400, Validation Loss: 10.292745589092437
# Epoch 125/400, Validation Loss: 10.312608926839163
# Epoch 126/400, Validation Loss: 10.239462815309908
# Epoch 127/400, Validation Loss: 10.375497186411716
# Epoch 128/400, Validation Loss: 10.440627295498828
# Epoch 129/400, Validation Loss: 10.37171418122189
# Epoch 130/400, Validation Loss: 10.291101993596664
# Epoch 131/400, Validation Loss: 10.329399614350944
# Epoch 132/400, Validation Loss: 10.386253498772836
# Epoch 133/400, Validation Loss: 10.322213138414577
# Epoch 134/400, Validation Loss: 10.4597522768548
# Epoch 135/400, Validation Loss: 10.557189041618184
# Epoch 136/400, Validation Loss: 10.330415361686068
# Epoch 137/400, Validation Loss: 10.322108249562353
# Epoch 138/400, Validation Loss: 10.391507958124212
# Epoch 139/400, Validation Loss: 10.28890876089186
# Epoch 140/400, Validation Loss: 10.346524661425343
# Epoch 141/400, Validation Loss: 10.288710083715836
# Epoch 142/400, Validation Loss: 10.332742013997352
# Epoch 143/400, Validation Loss: 10.404565178758455
# Epoch 144/400, Validation Loss: 10.288978629662704
# Epoch 145/400, Validation Loss: 10.256341598760772
# Epoch 146/400, Validation Loss: 10.279076094950163
# Epoch 147/400, Validation Loss: 10.422155302547385
# Epoch 148/400, Validation Loss: 10.324623477390016
# Epoch 149/400, Validation Loss: 10.369965978660144
# Epoch 150/400, Validation Loss: 10.437776191103785
# Epoch 151/400, Validation Loss: 10.386064898896475
# Epoch 152/400, Validation Loss: 10.364774529124128
# Epoch 153/400, Validation Loss: 10.368058023462401
# Epoch 154/400, Validation Loss: 10.354690229021703
# Epoch 155/400, Validation Loss: 10.284577552059053
# Epoch 156/400, Validation Loss: 10.412797727341424
# Epoch 157/400, Validation Loss: 10.410470920501098
# Epoch 158/400, Validation Loss: 10.627028928206764
# Epoch 159/400, Validation Loss: 10.524549814304692
# Epoch 160/400, Validation Loss: 10.499658705307791
# Epoch 161/400, Validation Loss: 10.48533274674557
# Epoch 162/400, Validation Loss: 10.385371311119915
# Epoch 163/400, Validation Loss: 10.374645864722067
# Epoch 164/400, Validation Loss: 10.415483128092646
# Epoch 165/400, Validation Loss: 10.426098895719491
# Epoch 166/400, Validation Loss: 10.347711918399014
# Epoch 167/400, Validation Loss: 10.391969476553689
# Epoch 168/400, Validation Loss: 10.396303431284673
# Epoch 169/400, Validation Loss: 10.351380132446733
# Epoch 170/400, Validation Loss: 10.494358761688227
# Epoch 171/400, Validation Loss: 10.567504706728851
# Epoch 172/400, Validation Loss: 10.441234193625458
# Epoch 173/400, Validation Loss: 10.567193136922452
# Epoch 174/400, Validation Loss: 10.471569469950374
# Epoch 175/400, Validation Loss: 10.351130765664879
# Epoch 176/400, Validation Loss: 10.498911116001882
# Epoch 177/400, Validation Loss: 10.304060825511261
# Epoch 178/400, Validation Loss: 10.506495318559615
# Epoch 179/400, Validation Loss: 10.515583100462603
# Epoch 180/400, Validation Loss: 10.455525596774228
# Epoch 181/400, Validation Loss: 10.353659582669408
# Epoch 182/400, Validation Loss: 10.42785898484755
# Epoch 183/400, Validation Loss: 10.59632082330863
# Epoch 184/400, Validation Loss: 10.546786539851487
# Epoch 185/400, Validation Loss: 10.498895043996026
# Epoch 186/400, Validation Loss: 10.613510858673484
# Epoch 187/400, Validation Loss: 10.57232022817365
# Epoch 188/400, Validation Loss: 10.524005823244645
# Epoch 189/400, Validation Loss: 10.445989847134063
# Epoch 190/400, Validation Loss: 10.512685652887589
# Epoch 191/400, Validation Loss: 10.367490411628943
# Epoch 192/400, Validation Loss: 10.352971219759317
# Epoch 193/400, Validation Loss: 10.337656593153126
# Epoch 194/400, Validation Loss: 10.471744559338221
# Epoch 195/400, Validation Loss: 10.418606244312478
# Epoch 196/400, Validation Loss: 10.58102421468102
# Epoch 197/400, Validation Loss: 10.528616531363914
# Epoch 198/400, Validation Loss: 10.458065543667933
# Epoch 199/400, Validation Loss: 10.432920948466352
# Epoch 200/400, Validation Loss: 10.48306283922572
# Epoch 201/400, Validation Loss: 10.680904732869891
# Epoch 202/400, Validation Loss: 10.537804650618252
# Epoch 203/400, Validation Loss: 10.509744720905175
# Epoch 204/400, Validation Loss: 10.63356342179377
# Epoch 205/400, Validation Loss: 10.587709838940786
# Epoch 206/400, Validation Loss: 10.53994834982531
# Epoch 207/400, Validation Loss: 10.522634638758596
# Epoch 208/400, Validation Loss: 10.53818955150686
# Epoch 209/400, Validation Loss: 10.523018183884556
# Epoch 210/400, Validation Loss: 10.620583548837981
# Epoch 211/400, Validation Loss: 10.566010895857048
# Epoch 212/400, Validation Loss: 10.733817772075534
# Epoch 213/400, Validation Loss: 10.51379088419039
# Epoch 214/400, Validation Loss: 10.590009162319157
# Epoch 215/400, Validation Loss: 10.51915440734173
# Epoch 216/400, Validation Loss: 10.490780653118918
# Epoch 217/400, Validation Loss: 10.438583826930877
# Epoch 218/400, Validation Loss: 10.698906434691462
# Epoch 219/400, Validation Loss: 10.607914338468936
# Epoch 220/400, Validation Loss: 10.601154640358804
# Epoch 221/400, Validation Loss: 10.522884984287458
# Epoch 222/400, Validation Loss: 10.599389634033642
# Epoch 223/400, Validation Loss: 10.580994057744487
# Epoch 224/400, Validation Loss: 10.738292881091903
# Epoch 225/400, Validation Loss: 10.701352522010612
# Epoch 226/400, Validation Loss: 10.685098137053822
# Epoch 227/400, Validation Loss: 10.577643244225087
# Epoch 228/400, Validation Loss: 10.63993017056646
# Epoch 229/400, Validation Loss: 10.562129188364452
# Epoch 230/400, Validation Loss: 10.543745948482961
# Epoch 231/400, Validation Loss: 10.653611572116628
# Epoch 232/400, Validation Loss: 10.70848993236957
# Epoch 233/400, Validation Loss: 10.593870377820195
# Epoch 234/400, Validation Loss: 10.57713671909294
# Epoch 235/400, Validation Loss: 10.759736314960719
# Epoch 236/400, Validation Loss: 10.766580963935162
# Epoch 237/400, Validation Loss: 10.68178155353109
# Epoch 238/400, Validation Loss: 10.628013778980835
# Epoch 239/400, Validation Loss: 10.716991889240106
# Epoch 240/400, Validation Loss: 10.490525532768057
# Epoch 241/400, Validation Loss: 10.556796575875582
# Epoch 242/400, Validation Loss: 10.69762954061552
# Epoch 243/400, Validation Loss: 10.634923027849704
# Epoch 244/400, Validation Loss: 10.611432330455964
# Epoch 245/400, Validation Loss: 10.685806103372755
# Epoch 246/400, Validation Loss: 10.667497900818358
# Epoch 247/400, Validation Loss: 10.728098985683982
# Epoch 248/400, Validation Loss: 10.878290334920857
# Epoch 249/400, Validation Loss: 10.718748291428971
# Epoch 250/400, Validation Loss: 10.733697134694467
# Epoch 251/400, Validation Loss: 10.783224408011197
# Epoch 252/400, Validation Loss: 10.801776380533429
# Epoch 253/400, Validation Loss: 10.880220132552413
# Epoch 254/400, Validation Loss: 10.653469568812975
# Epoch 255/400, Validation Loss: 10.647634611446426
# Epoch 256/400, Validation Loss: 10.726505155695119
# Epoch 257/400, Validation Loss: 10.782469122636241
# Epoch 258/400, Validation Loss: 10.80475177623148
# Epoch 259/400, Validation Loss: 10.759045734008744
# Epoch 260/400, Validation Loss: 10.811577362372756
# Epoch 261/400, Validation Loss: 10.873441080575306
# Epoch 262/400, Validation Loss: 10.769218380447304
# Epoch 263/400, Validation Loss: 10.743567811028177
# Epoch 264/400, Validation Loss: 10.760193980637547
# Epoch 265/400, Validation Loss: 10.778362253807202
# Epoch 266/400, Validation Loss: 10.689788384305208
# Epoch 267/400, Validation Loss: 10.70997601564647
# Epoch 268/400, Validation Loss: 10.786860601893846
# Epoch 269/400, Validation Loss: 10.645415809366236
# Epoch 270/400, Validation Loss: 10.711228950756102
# Epoch 271/400, Validation Loss: 10.70008873533105
# Epoch 272/400, Validation Loss: 10.689416564826052
# Epoch 273/400, Validation Loss: 10.819278798515834
# Epoch 274/400, Validation Loss: 10.966822224505064
# Epoch 275/400, Validation Loss: 10.865841318530741
# Epoch 276/400, Validation Loss: 10.72534371296631
# Epoch 277/400, Validation Loss: 10.824874059517086
# Epoch 278/400, Validation Loss: 10.765544518998986
# Epoch 279/400, Validation Loss: 10.834776286173252
# Epoch 280/400, Validation Loss: 10.885774295632455
# Epoch 281/400, Validation Loss: 10.904081943301478
# Epoch 282/400, Validation Loss: 10.907470065037565
# Epoch 283/400, Validation Loss: 10.835992745811883
# Epoch 284/400, Validation Loss: 11.237492887644155
# Epoch 285/400, Validation Loss: 10.997356396804387
# Epoch 286/400, Validation Loss: 10.923888059572198
# Epoch 287/400, Validation Loss: 10.763211307515594
# Epoch 288/400, Validation Loss: 10.91000592275282
# Epoch 289/400, Validation Loss: 10.849320442337165
# Epoch 290/400, Validation Loss: 10.760924040457848
# Epoch 291/400, Validation Loss: 10.828500535607029
# Epoch 292/400, Validation Loss: 10.865683364884962
# Epoch 293/400, Validation Loss: 10.749660247853374
# Epoch 294/400, Validation Loss: 10.773842532759428
# Epoch 295/400, Validation Loss: 10.897005954770954
# Epoch 296/400, Validation Loss: 10.920344211105382
# Epoch 297/400, Validation Loss: 10.717516285548726
# Epoch 298/400, Validation Loss: 10.763342106248029
# Epoch 299/400, Validation Loss: 10.794129176803327
# Epoch 300/400, Validation Loss: 10.82288203367218
# Epoch 301/400, Validation Loss: 10.933398835259027
# Epoch 302/400, Validation Loss: 10.999014926060253
# Epoch 303/400, Validation Loss: 10.905709308344743
# Epoch 304/400, Validation Loss: 10.829793146659963
# Epoch 305/400, Validation Loss: 10.78084390418658
# Epoch 306/400, Validation Loss: 10.891817669390743
# Epoch 307/400, Validation Loss: 10.878758697776401
# Epoch 308/400, Validation Loss: 10.946589285242624
# Epoch 309/400, Validation Loss: 10.976275057874824
# Epoch 310/400, Validation Loss: 10.965380272705659
# Epoch 311/400, Validation Loss: 11.02020661638544
# Epoch 312/400, Validation Loss: 10.95055729200971
# Epoch 313/400, Validation Loss: 11.024360724949819
# Epoch 314/400, Validation Loss: 10.941623471830468
# Epoch 315/400, Validation Loss: 10.91219941095202
# Epoch 316/400, Validation Loss: 10.993813986076377
# Epoch 317/400, Validation Loss: 10.886432151277495
# Epoch 318/400, Validation Loss: 10.936413629302725
# Epoch 319/400, Validation Loss: 11.038153359665758
# Epoch 320/400, Validation Loss: 10.868518653773029
# Epoch 321/400, Validation Loss: 10.983699775282556
# Epoch 322/400, Validation Loss: 10.957452757208765
# Epoch 323/400, Validation Loss: 10.96606467542396
# Epoch 324/400, Validation Loss: 10.973102883257473
# Epoch 325/400, Validation Loss: 10.899897019753134
# Epoch 326/400, Validation Loss: 11.042462256835583
# Epoch 327/400, Validation Loss: 10.984503699514113
# Epoch 328/400, Validation Loss: 11.00531570648296
# Epoch 329/400, Validation Loss: 10.908228288039945
# Epoch 330/400, Validation Loss: 10.85603110224645
# Epoch 331/400, Validation Loss: 10.906567013358863
# Epoch 332/400, Validation Loss: 10.836479640587452
# Epoch 333/400, Validation Loss: 10.902827337364945
# Epoch 334/400, Validation Loss: 10.903237423513932
# Epoch 335/400, Validation Loss: 11.049593532218214
# Epoch 336/400, Validation Loss: 10.950855815150316
# Epoch 337/400, Validation Loss: 11.011307283860338
# Epoch 338/400, Validation Loss: 10.94843041593783
# Epoch 339/400, Validation Loss: 10.869850748438576
# Epoch 340/400, Validation Loss: 11.032749120864343
# Epoch 341/400, Validation Loss: 10.901705538220249
# Epoch 342/400, Validation Loss: 10.918856438484063
# Epoch 343/400, Validation Loss: 10.95443999007502
# Epoch 344/400, Validation Loss: 11.048602956460567
# Epoch 345/400, Validation Loss: 10.93713968147713
# Epoch 346/400, Validation Loss: 10.958266669756801
# Epoch 347/400, Validation Loss: 10.92780225622721
# Epoch 348/400, Validation Loss: 10.93609416317681
# Epoch 349/400, Validation Loss: 11.105276470677968
# Epoch 350/400, Validation Loss: 10.980715822119743
# Epoch 351/400, Validation Loss: 11.004696720474044
# Epoch 352/400, Validation Loss: 10.874607064905485
# Epoch 353/400, Validation Loss: 10.985974263022038
# Epoch 354/400, Validation Loss: 11.002555770970696
# Epoch 355/400, Validation Loss: 10.967456218503369
# Epoch 356/400, Validation Loss: 10.982933214759571
# Epoch 357/400, Validation Loss: 11.098341531739932
# Epoch 358/400, Validation Loss: 11.04483864554235
# Epoch 359/400, Validation Loss: 11.023713222326467
# Epoch 360/400, Validation Loss: 10.874669128109215
# Epoch 361/400, Validation Loss: 11.003220250655957
# Epoch 362/400, Validation Loss: 11.115039502862547
# Epoch 363/400, Validation Loss: 11.057877056429342
# Epoch 364/400, Validation Loss: 11.031391369481675
# Epoch 365/400, Validation Loss: 11.117681017280963
# Epoch 366/400, Validation Loss: 10.949543311772896
# Epoch 367/400, Validation Loss: 10.848756783661305
# Epoch 368/400, Validation Loss: 10.8816169933711
# Epoch 369/400, Validation Loss: 10.938214237956647
# Epoch 370/400, Validation Loss: 10.892378931541586
# Epoch 371/400, Validation Loss: 10.902114140810081
# Epoch 372/400, Validation Loss: 11.025764875440142
# Epoch 373/400, Validation Loss: 10.971292657022568
# Epoch 374/400, Validation Loss: 11.159782995053188
# Epoch 375/400, Validation Loss: 11.117494180718689
# Epoch 376/400, Validation Loss: 10.925237871990644
# Epoch 377/400, Validation Loss: 10.956423003311942
# Epoch 378/400, Validation Loss: 11.045297889075357
# Epoch 379/400, Validation Loss: 11.022371857051594
# Epoch 380/400, Validation Loss: 11.040451052964581
# Epoch 381/400, Validation Loss: 10.95046152876213
# Epoch 382/400, Validation Loss: 10.982856942072113
# Epoch 383/400, Validation Loss: 11.04673293427361
# Epoch 384/400, Validation Loss: 11.02850589874458
# Epoch 385/400, Validation Loss: 11.163902895079937
# Epoch 386/400, Validation Loss: 11.044192593822576
# Epoch 387/400, Validation Loss: 11.034009725904655
# Epoch 388/400, Validation Loss: 11.081333258025746
# Epoch 389/400, Validation Loss: 11.085577581842987
# Epoch 390/400, Validation Loss: 11.21317893807993
# Epoch 391/400, Validation Loss: 11.105310789980125
# Epoch 392/400, Validation Loss: 11.039244248904051
# Epoch 393/400, Validation Loss: 10.979665084730835
# Epoch 394/400, Validation Loss: 11.019547403733823
# Epoch 395/400, Validation Loss: 10.998974781338244
# Epoch 396/400, Validation Loss: 10.96671771555015
# Epoch 397/400, Validation Loss: 10.964182212907378
# Epoch 398/400, Validation Loss: 10.969147085972832
# Epoch 399/400, Validation Loss: 11.013777869697474
# Epoch 400/400, Validation Loss: 11.028666111887986

# %%
a_val, b_val = model.a.item(), model.b.item()

# Generate predictions for plotting
end_fit_x = [x_all[0], x_all[-1]]
end_fit_y = [a_val * x + b_val for x in end_fit_x] # this is the calculated / estimated fit with a and b from the 400 epoch model
true_fn_y = [a0 * x + b0 for x in end_fit_x]  # Assuming a0 and b0 are known true values

# Plotting
fig, axs = plt.subplots(2, 1, figsize=(10, 8))

# Plotting data points and model predictions
axs[0].plot(x_train, y_train, 'ro', x_val, y_val, 'b^', end_fit_x, end_fit_y, 'g')
axs[0].legend(('training points', 'test points', 'final fit'), loc='upper left')

# Assuming training and validation loss history are stored in lists: train_loss_history and val_loss_history
epochs = range(1, len(train_loss_history) + 1)

# Plotting loss history
axs[1].semilogy(epochs, train_loss_history, 'r')
axs[1].semilogy(epochs, val_loss_history, 'b')
axs[1].legend(('training loss', 'validation loss'), loc='upper right')

plt.show()

# %% [markdown]
# ## 3. Exercise 1
#
# Play with the true function parameters ```a0, b0, s0``` and the ``batch_size`` value, check how it affects the convergence.
#
# 1. How change of `s0` affects convergance?
# 2. When one should stop training to prevent overfitting?
#
# ---
#
# 1. `s0` affects convergance that the spread between the data points gets wider the larger `s0` gets. The graph in turn becomes wider as well
# 2. When training loss and validation loss lines cross
#
#
# ## 4. Training loop
#
# The training as we just saw is done iteratively, by adjusting the model parameters.
#
# We perform optimization several times for all traininng dataset. Going through all this dataset is refered to as 'epoch'.
#
# When we do training its usually done in two loops. In outer loop we iterate over all epochs. For each epoch we usually split the dataset into small chuncks, batches, and optimization it performed for all of those.
#
# It is important that data doesn't go to the training pipeline in same order. So the overall scheme looks like this (pseudocode):
#
#
# ```
# x,y = get_training_data()
# for epoch in range(number_epochs):
#    x_shfl,y_shfl = shuffle(x,y)
#
#    for mb_idx in range(number_minibatches_in_batch):
#        x_mb,y_mb = get_minibatch(x_shfl,y_shfl, mb_idx)
#
#        optimize_on(data=x_mb, labels=y_mb)
# ```
#
# ## 5. Bulding blocks of a neural network
#
# Neural network consists of layers of neurons. Each neuron perfroms 2 operations.
#
# <img src="https://github.com/neworldemancer/BMLWS/raw/main/figures/Perceptron.png" alt="drawing" width="30%"/>
#
# Each neuron performs 2 operations.
#
# 1. Calculate the linear transformation of the input vector $\mathbf{x}_i$:
# $$z_i = \mathbf{w} \cdot \mathbf{x}_i + b = \sum_j {w_j x_{ij}} + b$$ where $\mathbf{w}$ is a weight vector and $b$ - a bias, and $j$ traverses each dimension of the input vector
# 2. Perform the nonlinear transformation of the result using the activation function $f$ $$y_i = f(z_i)$$
#
# In a fully connected neural network, each layer is a set of N neurons, performing different transformations of the input $\mathbf{x}_i$ of the same layer, now producing an output **vector** $ \mathbf{y} _i = f(\mathbf{z}_i) = f(W\mathbf{x}_i + \mathbf{b})$ now with a bias vector $\mathbf{b}$ and a * *matrix** of weights $W$.
#
# Since the output of each layer constitutes the input to the next layer, we can write for layer $l$: $$\mathbf{x}^l_i = f^{l-1}(\mathbf{W}^{ l-1} \mathbf{x}^{ l-1}_i + \mathbf{b}^{l-1})$$ where $\mathbf{x}_i^{l=0}$ is the vector d 'network input for data point $i$.
#
# <img src="https://github.com/neworldemancer/BMLWS/raw/main/figures/MLP.png" alt="drawing" width="50%"/>
#
# To simplify building the network, we'll define a helper function, creating neuron layer with given number of outputs:

# %%
class Dense(nn.Module):
    def __init__(self, input_units, output_units, activation=None):
        """
        Fully connected layer implemented with explicit matrix multiplication.

        Parameters
        ----------
        input_units : int
            Number of input neurons
        output_units : int
            Number of output neurons
        activation : callable or None, optional
            Non-linear activation function (e.g., F.relu)
        """
        super(Dense, self).__init__()
        self.input_units = int(input_units)
        self.output_units = int(output_units)
        self.activation = activation

        # Initialize weights and biases
        self.weights = nn.Parameter(torch.randn(input_units, output_units))
        self.bias = nn.Parameter(torch.randn(output_units))

    def forward(self, x):
        """
        Forward pass through the layer.

        Parameters
        ----------
        x : torch.Tensor
            Input tensor

        Returns
        -------
        torch.Tensor
            Output of the layer
        """

        outputs = torch.matmul(x, self.weights) + self.bias

        # Apply activation function if provided
        if self.activation is not None:
            # Check if the activation function is softmax
            if self.activation == F.softmax:
                # Apply softmax with specified dimension
                outputs = self.activation(outputs, dim=1)
            else:
                # apply other activation functions normally
                outputs = self.activation(outputs)

        return outputs

# %% [markdown]
# In the case of multi-class classification, in the last layer, we can use the *softmax* transformation as a non-linear transformation. The softmax for the $j$th element of $\mathbf{z}_i$ is $$y_{ij} = \frac{e^{z_{ij}}}{\sum_{k=1}^{K} e^{z_{ik}}}$$ where $K$ is the total number of classes.
#
#
# For example. before softmax $$[1.0, 2.0, 3.0, \mathbf{4.0} ]$$ and after: $$[0.0321, 0.0871, 0.2369, \mathbf{0.6439}]$$ (now the sum is equal to one)
#
# We can also now compare the fundamental truth which could be $$[0,0,0,\mathbf{1}]$$ That is to say that class 4 is the good class and that the network predicted correctly.
# ## 6. Bulding a neural network
#
# https://medium.com/geekculture/how-visualizations-help-make-sense-of-deep-learning-a408ab00688f

# %%
n_input = 10
n_output = 2
num_datapoints = 1
input_tensor = torch.randn(num_datapoints, n_input)
dense = Dense(input_units=n_input , output_units=n_output, activation=torch.sigmoid)


# remember to matrix multiply A and B we need the shapes (a1 x a2) (b1 x b2) to be such that a2=b1
# the result will be (a1 x b2)

print(dense.weights.shape)
print(input_tensor.shape)
print(torch.matmul(input_tensor, dense.weights).shape) # this is XW  e.g. (1, 10)x(10, 2) = (1 x 2)

# notice that increasing the number of data points does not change the shape of W!
# This is important - the parameter shape should not change according to the number of datapoints, only their dimenaionality

# %%
# if we want to stack multiple dense operations together ## for more than 2 dense layers
#hidden_dim = 10 # number of units that go into the layer (width?)
#hidden_dim_2 = 5
#dense1 =  Dense(input_units=n_input , output_units=hidden_dim, activation=torch.sigmoid)
#dense2 =  Dense(input_units=hidden_dim , output_units=hidden_dim_2, activation=torch.sigmoid)
#dense3 =  Dense(input_units=hidden_dim_2, output_units=n_output, activation=F.softmax) # output of the dense1 layer is the input of the dense2 layer
#output = dense3(dense2(dense1(input_tensor)))

# %%
# if we want to stack multiple dense operations together
hidden_dim = 10 # number of units that go into the layer (width?)
dense1 =  Dense(input_units=n_input , output_units=hidden_dim, activation=torch.sigmoid)
dense2 =  Dense(input_units=hidden_dim , output_units=hidden_dim_2, activation=torch.sigmoid)
#dense3 =  Dense(input_units=hidden_dim_2, output_units=n_output, activation=F.softmax) # output of the dense1 layer is the input of the dense2 layer
output = dense2(dense1(input_tensor))

# %%
# integrate everything into an overall model

class MyModel(nn.Module):
    def __init__(self, input_units, hidden_units, output_units):
        super(MyModel, self).__init__()
        # Define a Dense layer
        self.dense1 = Dense(input_units, hidden_units, activation=F.relu)
        # Define another Dense layer
        self.dense2 = Dense(hidden_units, output_units, activation=F.softmax)

    def forward(self, x):
        x = self.dense1(x)
        x = self.dense2(x)
        return x

    def predict(self, x):
        # Forward pass and get predictions
        preds = self.dense2(self.dense1(x))
        print(preds)  # to check values before argmax
        return torch.argmax(preds, dim=1)

# Example usage
input_units = 10
hidden_units = 5
output_units = 2
model = MyModel(input_units, hidden_units, output_units)

# Create a sample input tensor
input_tensor = torch.randn(5, input_units)

# Get predictions
predictions = model.predict(input_tensor)
print(predictions)
